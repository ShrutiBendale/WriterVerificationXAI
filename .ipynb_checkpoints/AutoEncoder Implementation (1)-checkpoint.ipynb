# %%
from keras import losses
from keras.models import Model
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.layers import Input, Conv2D, MaxPooling2D, BatchNormalization, Activation, Reshape, UpSampling2D, Dense
from keras.layers.merge import concatenate
from keras.layers import Flatten
from keras.utils import to_categorical
from keras.optimizers import Adadelta, SGD, Adam
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
#from scipy.misc import imresize
from keras.layers import concatenate
from keras.utils.vis_utils import model_to_dot
from keras.utils import np_utils
from IPython.display import SVG
import matplotlib.pyplot as plt
import os
import numpy as np
import random
import cv2
import time
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Importing data

# %%
features_data = pd.read_csv("15features.csv")
training_data = pd.read_csv("seen-dataset/dataset_seen_training_siamese.csv")
validation_data = pd.read_csv("seen-dataset/dataset_seen_validation_siamese.csv")

training_data = training_data.drop('Unnamed: 0',1)
validation_data = validation_data.drop('Unnamed: 0',1)

train_path = 'seen-dataset/TrainingSet/'
train_images = os.listdir(train_path)
#print(len(train_images))
val_path = 'seen-dataset/ValidationSet/'
val_images = os.listdir(val_path)

columns = features_data.columns

#Get the unique no of values a given feature can take.
features_values = []
for i in columns[1:]:
    #print(i)
    features_values.append(features_data[i].unique().shape[0])
features_values
# Out:
# [2, 3, 3, 3, 2, 2, 4, 2, 2, 4, 2, 3, 4, 2, 2]

# %% [markdown]
# ## Datagen

# %%
def datagen(batch_size,image_path,list_of_writers, vshift = (-64,64) ,vis=False):
    counter = 0
    w_ids,ids,x,y,imagenames, feature_list = [],[],[],[],[],[]
    while True:
#         counter = 0
        # for writer in unique_writers:
        #     print(identitycounter*100/stop_at, end='\r')
        
        writer_index = np.random.randint(0,len(list_of_writers))
        
#         for writer_index in writer_indexes:
#             class_vectors = []
#             features = None
        imagename = list_of_writers[writer_index]
#             print('-->',csv_data['imagename'][0],imagename)
#             display(csv_data[csv_data['imagename']==imagename].values[0][1:])
        features = features_data[features_data['imagename']==imagename].values
        if len(features)==0:
#             print('no features', imagename)
            continue
        features = features[0][1:]-1

        loaded_image = cv2.imread(os.path.join(image_path,imagename),0)
        rand = np.random.randint(vshift[0],vshift[1])
        loaded_image_shifted=np.roll(axis=0,a=loaded_image,shift=rand)

        x.append(255.0-loaded_image_shifted.reshape((64,64,1)))
        y.append(255.0-loaded_image.reshape((64,64,1)))
        w_ids.append(imagename[:4])
        imagenames.append(imagename)
        ids.append(writer_index)
        feature_list.append(features)
#         print(imagename)
        counter+=1
#         print('counter:', counter, end='\r')
        if counter == batch_size:
            counter=0
            feature_list = np.array(feature_list)
            feature_list = feature_list.transpose()
            out_cat_features = []
            for i in range(len(feature_list)):
#                 print(feature_list[1])
                out_cat_features.append(to_categorical(feature_list[i],num_classes=features_values[i]))
            if vis== True:
                yield np.array(x)/255.0,[np.array(w_ids),np.array(imagenames)]
            else:
                yield np.array(x)/255.0,out_cat_features
            w_ids,ids,x,y,imagenames,feature_list =[], [],[], [],[],[]

# %% [markdown]
# ## AutoEncoder

# %%
input_img = Input(shape=(64, 64, 1))  # adapt this if using `channels_first` image data format

x = Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same', name='encoded')(x)
# encoded = GlobalAveragePooling2D()(x)

# encoder = Model(input_img, encoded)
# encoder.summary()
# print(encoded.shape)
# encoded = Flatten()(x)
# encoded = Dense(8*8*8)(encoded)
# # model = Model(input_img,encoded)
# # print(model.summary())
# # at this point the representation is (4, 4, 8) i.e. 128-dimensional
# r = Reshape(target_shape=(8,8,8))(encoded)
x = Conv2D(512, (3, 3), activation='relu', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same',name='output')(x)

autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy', metrics=['accuracy'])
autoencoder.summary()
# Out:
# WARNING:tensorflow:From C:\Users\argad\Anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 64, 64, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 4, 256)         295168
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 2, 2, 512)         1180160
# _________________________________________________________________
# encoded (MaxPooling2D)       (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 1, 1, 512)         2359808
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 2, 2, 256)         1179904
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 4, 128)         295040
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 8, 8, 64)          73792
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 16, 16, 32)        18464
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 32, 32, 16)        4624
# _________________________________________________________________
# up_sampling2d_6 (UpSampling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# output (Conv2D)              (None, 64, 64, 1)         145
# =================================================================
# Total params: 5,504,257
# Trainable params: 5,504,257
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##  Generators

# %%
train_path = 'seen-dataset/TrainingSet/'
train_images = os.listdir(train_path)
#len(train_images)
val_path = 'seen-dataset/ValidationSet/'
val_images = os.listdir(val_path)
#len(val_images)

train_list_of_writers = train_images
val_list_of_writers = val_images
batch_size = 64

training_datagen = datagen(batch_size,train_path,train_list_of_writers, hshift = (-10,10))
validation_datagen = datagen(batch_size,val_path,val_list_of_writers, hshift = (-10,10))

# %% [markdown]
# ## SVG

# %%
#SVG(model_to_dot(autoencoder, show_layer_names=True, show_shapes=True).create(prog='dot', format='svg'))

# %% [markdown]
# ## Model Checkpoint and Early Stopping

# %%
mc = ModelCheckpoint(filepath='saved-model_mc.h5', 
                     monitor='val_loss',period=1,save_best_only=True,save_weights_only=True,mode='auto',verbose=3)
es = EarlyStopping(patience=10000, monitor='val_loss', min_delta=0.0005, mode='auto')
#autoencoder.load_weights('simple_ae_maxpool_less_weights_v3.h5')

# %% [markdown]
# ## Fitting the generator

# %%
EPOCHS = 5000

hist = autoencoder.fit_generator(training_datagen, callbacks=[mc,es]
                                    , epochs=EPOCHS
                                    , steps_per_epoch = 1
                                    , validation_data = validation_datagen
                                    , validation_steps = 1
                                    , verbose = 3                                    
                                   )
autoencoder.save_weights("saved-model_v2.h5")
encoder = Model(inputs=autoencoder.inputs,outputs=autoencoder.get_layer('encoded').output)
# Out:
# WARNING:tensorflow:From C:\Users\argad\Anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/5000
#
# Epoch 00001: val_loss improved from inf to 0.69097, saving model to saved-model_mc.h5
# Epoch 2/5000
#
# Epoch 00002: val_loss improved from 0.69097 to 0.68674, saving model to saved-model_mc.h5
# Epoch 3/5000
#
# Epoch 00003: val_loss improved from 0.68674 to 0.67984, saving model to saved-model_mc.h5
# Epoch 4/5000
#
# Epoch 00004: val_loss improved from 0.67984 to 0.66774, saving model to saved-model_mc.h5
# Epoch 5/5000
#
# Epoch 00005: val_loss improved from 0.66774 to 0.64442, saving model to saved-model_mc.h5
# Epoch 6/5000
#
# Epoch 00006: val_loss improved from 0.64442 to 0.59296, saving model to saved-model_mc.h5
# Epoch 7/5000
#
# Epoch 00007: val_loss improved from 0.59296 to 0.45798, saving model to saved-model_mc.h5
# Epoch 8/5000
#
# Epoch 00008: val_loss improved from 0.45798 to 0.32121, saving model to saved-model_mc.h5
# Epoch 9/5000
#
# Epoch 00009: val_loss did not improve from 0.32121
# Epoch 10/5000
#
# Epoch 00010: val_loss improved from 0.32121 to 0.29931, saving model to saved-model_mc.h5
# Epoch 11/5000
#
# Epoch 00011: val_loss did not improve from 0.29931
# Epoch 12/5000
#
# Epoch 00012: val_loss did not improve from 0.29931
# Epoch 13/5000
#
# Epoch 00013: val_loss did not improve from 0.29931
# Epoch 14/5000
#
# Epoch 00014: val_loss improved from 0.29931 to 0.29740, saving model to saved-model_mc.h5
# Epoch 15/5000
#
# Epoch 00015: val_loss did not improve from 0.29740
# Epoch 16/5000
#
# Epoch 00016: val_loss improved from 0.29740 to 0.27732, saving model to saved-model_mc.h5
# Epoch 17/5000
#
# Epoch 00017: val_loss improved from 0.27732 to 0.27001, saving model to saved-model_mc.h5
# Epoch 18/5000
#
# Epoch 00018: val_loss improved from 0.27001 to 0.26022, saving model to saved-model_mc.h5
# Epoch 19/5000
#
# Epoch 00019: val_loss did not improve from 0.26022
# Epoch 20/5000
#
# Epoch 00020: val_loss did not improve from 0.26022
# Epoch 21/5000
#
# Epoch 00021: val_loss did not improve from 0.26022
# Epoch 22/5000
#
# Epoch 00022: val_loss improved from 0.26022 to 0.22165, saving model to saved-model_mc.h5
# Epoch 23/5000
#
# Epoch 00023: val_loss improved from 0.22165 to 0.22103, saving model to saved-model_mc.h5
# Epoch 24/5000
#
# Epoch 00024: val_loss improved from 0.22103 to 0.20624, saving model to saved-model_mc.h5
# Epoch 25/5000
#
# Epoch 00025: val_loss improved from 0.20624 to 0.20298, saving model to saved-model_mc.h5
# Epoch 26/5000
#
# Epoch 00026: val_loss improved from 0.20298 to 0.19601, saving model to saved-model_mc.h5
# Epoch 27/5000
#
# Epoch 00027: val_loss improved from 0.19601 to 0.19545, saving model to saved-model_mc.h5
# Epoch 28/5000
#
# Epoch 00028: val_loss did not improve from 0.19545
# Epoch 29/5000
#
# Epoch 00029: val_loss improved from 0.19545 to 0.19465, saving model to saved-model_mc.h5
# Epoch 30/5000
#
# Epoch 00030: val_loss improved from 0.19465 to 0.19341, saving model to saved-model_mc.h5
# Epoch 31/5000
#
# Epoch 00031: val_loss improved from 0.19341 to 0.18970, saving model to saved-model_mc.h5
# Epoch 32/5000
#
# Epoch 00032: val_loss did not improve from 0.18970
# Epoch 33/5000
#
# Epoch 00033: val_loss improved from 0.18970 to 0.18289, saving model to saved-model_mc.h5
# Epoch 34/5000
#
# Epoch 00034: val_loss improved from 0.18289 to 0.17709, saving model to saved-model_mc.h5
# Epoch 35/5000
#
# Epoch 00035: val_loss did not improve from 0.17709
# Epoch 36/5000
#
# Epoch 00036: val_loss did not improve from 0.17709
# Epoch 37/5000
#
# Epoch 00037: val_loss did not improve from 0.17709
# Epoch 38/5000
#
# Epoch 00038: val_loss did not improve from 0.17709
# Epoch 39/5000
#
# Epoch 00039: val_loss did not improve from 0.17709
# Epoch 40/5000
#
# Epoch 00040: val_loss did not improve from 0.17709
# Epoch 41/5000
#
# Epoch 00041: val_loss did not improve from 0.17709
# Epoch 42/5000
#
# Epoch 00042: val_loss did not improve from 0.17709
# Epoch 43/5000
#
# Epoch 00043: val_loss did not improve from 0.17709
# Epoch 44/5000
#
# Epoch 00044: val_loss did not improve from 0.17709
# Epoch 45/5000
#
# Epoch 00045: val_loss did not improve from 0.17709
# Epoch 46/5000
#
# Epoch 00046: val_loss did not improve from 0.17709
# Epoch 47/5000
#
# Epoch 00047: val_loss did not improve from 0.17709
# Epoch 48/5000
#
# Epoch 00048: val_loss did not improve from 0.17709
# Epoch 49/5000
#
# Epoch 00049: val_loss did not improve from 0.17709
# Epoch 50/5000
#
# Epoch 00050: val_loss did not improve from 0.17709
# Epoch 51/5000
#
# Epoch 00051: val_loss did not improve from 0.17709
# Epoch 52/5000
#
# Epoch 00052: val_loss improved from 0.17709 to 0.17555, saving model to saved-model_mc.h5
# Epoch 53/5000
#
# Epoch 00053: val_loss improved from 0.17555 to 0.17394, saving model to saved-model_mc.h5
# Epoch 54/5000
#
# Epoch 00054: val_loss did not improve from 0.17394
# Epoch 55/5000
#
# Epoch 00055: val_loss did not improve from 0.17394
# Epoch 56/5000
#
# Epoch 00056: val_loss did not improve from 0.17394
# Epoch 57/5000
#
# Epoch 00057: val_loss improved from 0.17394 to 0.17250, saving model to saved-model_mc.h5
# Epoch 58/5000
#
# Epoch 00058: val_loss improved from 0.17250 to 0.17042, saving model to saved-model_mc.h5
# Epoch 59/5000
#
# Epoch 00059: val_loss did not improve from 0.17042
# Epoch 60/5000
#
# Epoch 00060: val_loss did not improve from 0.17042
# Epoch 61/5000
#
# Epoch 00061: val_loss did not improve from 0.17042
# Epoch 62/5000
#
# Epoch 00062: val_loss did not improve from 0.17042
# Epoch 63/5000
#
# Epoch 00063: val_loss did not improve from 0.17042
# Epoch 64/5000
#
# Epoch 00064: val_loss did not improve from 0.17042
# Epoch 65/5000
#
# Epoch 00065: val_loss did not improve from 0.17042
# Epoch 66/5000
#
# Epoch 00066: val_loss did not improve from 0.17042
# Epoch 67/5000
#
# Epoch 00067: val_loss did not improve from 0.17042
# Epoch 68/5000
#
# Epoch 00068: val_loss did not improve from 0.17042
# Epoch 69/5000
#
# Epoch 00069: val_loss did not improve from 0.17042
# Epoch 70/5000
#
# Epoch 00070: val_loss did not improve from 0.17042
# Epoch 71/5000
#
# Epoch 00071: val_loss did not improve from 0.17042
# Epoch 72/5000
#
# Epoch 00072: val_loss did not improve from 0.17042
# Epoch 73/5000
#
# Epoch 00073: val_loss did not improve from 0.17042
# Epoch 74/5000
#
# Epoch 00074: val_loss did not improve from 0.17042
# Epoch 75/5000
#
# Epoch 00075: val_loss did not improve from 0.17042
# Epoch 76/5000
#
# Epoch 00076: val_loss did not improve from 0.17042
# Epoch 77/5000
#
# Epoch 00077: val_loss improved from 0.17042 to 0.16556, saving model to saved-model_mc.h5
# Epoch 78/5000
#
# Epoch 00078: val_loss did not improve from 0.16556
# Epoch 79/5000
#
# Epoch 00079: val_loss did not improve from 0.16556
# Epoch 80/5000
#
# Epoch 00080: val_loss did not improve from 0.16556
# Epoch 81/5000
#
# Epoch 00081: val_loss did not improve from 0.16556
# Epoch 82/5000
#
# Epoch 00082: val_loss did not improve from 0.16556
# Epoch 83/5000
#
# Epoch 00083: val_loss did not improve from 0.16556
# Epoch 84/5000
#
# Epoch 00084: val_loss did not improve from 0.16556
# Epoch 85/5000
#
# Epoch 00085: val_loss did not improve from 0.16556
# Epoch 86/5000
#
# Epoch 00086: val_loss did not improve from 0.16556
# Epoch 87/5000
#
# Epoch 00087: val_loss did not improve from 0.16556
# Epoch 88/5000
#
# Epoch 00088: val_loss did not improve from 0.16556
# Epoch 89/5000
#
# Epoch 00089: val_loss did not improve from 0.16556
# Epoch 90/5000
#
# Epoch 00090: val_loss did not improve from 0.16556
# Epoch 91/5000
#
# Epoch 00091: val_loss improved from 0.16556 to 0.16178, saving model to saved-model_mc.h5
# Epoch 92/5000
#
# Epoch 00092: val_loss did not improve from 0.16178
# Epoch 93/5000
#
# Epoch 00093: val_loss did not improve from 0.16178
# Epoch 94/5000
#
# Epoch 00094: val_loss did not improve from 0.16178
# Epoch 95/5000
#
# Epoch 00095: val_loss did not improve from 0.16178
# Epoch 96/5000
#
# Epoch 00096: val_loss did not improve from 0.16178
# Epoch 97/5000
#
# Epoch 00097: val_loss did not improve from 0.16178
# Epoch 98/5000
#
# Epoch 00098: val_loss did not improve from 0.16178
# Epoch 99/5000
#
# Epoch 00099: val_loss did not improve from 0.16178
# Epoch 100/5000
#
# Epoch 00100: val_loss did not improve from 0.16178
# Epoch 101/5000
#
# Epoch 00101: val_loss did not improve from 0.16178
# Epoch 102/5000
#
# Epoch 00102: val_loss did not improve from 0.16178
# Epoch 103/5000
#
# Epoch 00103: val_loss did not improve from 0.16178
# Epoch 104/5000
#
# Epoch 00104: val_loss did not improve from 0.16178
# Epoch 105/5000
#
# Epoch 00105: val_loss did not improve from 0.16178
# Epoch 106/5000
#
# Epoch 00106: val_loss did not improve from 0.16178
# Epoch 107/5000
#
# Epoch 00107: val_loss did not improve from 0.16178
# Epoch 108/5000
#
# Epoch 00108: val_loss did not improve from 0.16178
# Epoch 109/5000
#
# Epoch 00109: val_loss did not improve from 0.16178
# Epoch 110/5000
#
# Epoch 00110: val_loss did not improve from 0.16178
# Epoch 111/5000
#
# Epoch 00111: val_loss did not improve from 0.16178
# Epoch 112/5000
#
# Epoch 00112: val_loss did not improve from 0.16178
# Epoch 113/5000
#
# Epoch 00113: val_loss did not improve from 0.16178
# Epoch 114/5000
#
# Epoch 00114: val_loss did not improve from 0.16178
# Epoch 115/5000
#
# Epoch 00115: val_loss did not improve from 0.16178
# Epoch 116/5000
#
# Epoch 00116: val_loss did not improve from 0.16178
# Epoch 117/5000
#
# Epoch 00117: val_loss did not improve from 0.16178
# Epoch 118/5000
#
# Epoch 00118: val_loss did not improve from 0.16178
# Epoch 119/5000
#
# Epoch 00119: val_loss did not improve from 0.16178
# Epoch 120/5000
#
# Epoch 00120: val_loss did not improve from 0.16178
# Epoch 121/5000
#
# Epoch 00121: val_loss did not improve from 0.16178
# Epoch 122/5000
#
# Epoch 00122: val_loss did not improve from 0.16178
# Epoch 123/5000
#
# Epoch 00123: val_loss did not improve from 0.16178
# Epoch 124/5000
#
# Epoch 00124: val_loss did not improve from 0.16178
# Epoch 125/5000
#
# Epoch 00125: val_loss did not improve from 0.16178
# Epoch 126/5000
#
# Epoch 00126: val_loss did not improve from 0.16178
# Epoch 127/5000
#
# Epoch 00127: val_loss improved from 0.16178 to 0.16081, saving model to saved-model_mc.h5
# Epoch 128/5000
#
# Epoch 00128: val_loss did not improve from 0.16081
# Epoch 129/5000
#
# Epoch 00129: val_loss did not improve from 0.16081
# Epoch 130/5000
#
# Epoch 00130: val_loss did not improve from 0.16081
# Epoch 131/5000
#
# Epoch 00131: val_loss did not improve from 0.16081
# Epoch 132/5000
#
# Epoch 00132: val_loss did not improve from 0.16081
# Epoch 133/5000
#
# Epoch 00133: val_loss did not improve from 0.16081
# Epoch 134/5000
#
# Epoch 00134: val_loss did not improve from 0.16081
# Epoch 135/5000
#
# Epoch 00135: val_loss did not improve from 0.16081
# Epoch 136/5000
#
# Epoch 00136: val_loss did not improve from 0.16081
# Epoch 137/5000
#
# Epoch 00137: val_loss did not improve from 0.16081
# Epoch 138/5000
#
# Epoch 00138: val_loss did not improve from 0.16081
# Epoch 139/5000
#
# Epoch 00139: val_loss did not improve from 0.16081
# Epoch 140/5000
#
# Epoch 00140: val_loss did not improve from 0.16081
# Epoch 141/5000
#
# Epoch 00141: val_loss did not improve from 0.16081
# Epoch 142/5000
#
# Epoch 00142: val_loss did not improve from 0.16081
# Epoch 143/5000
#
# Epoch 00143: val_loss did not improve from 0.16081
# Epoch 144/5000
#
# Epoch 00144: val_loss did not improve from 0.16081
# Epoch 145/5000
#
# Epoch 00145: val_loss did not improve from 0.16081
# Epoch 146/5000
#
# Epoch 00146: val_loss did not improve from 0.16081
# Epoch 147/5000
#
# Epoch 00147: val_loss did not improve from 0.16081
# Epoch 148/5000
#
# Epoch 00148: val_loss did not improve from 0.16081
# Epoch 149/5000
#
# Epoch 00149: val_loss did not improve from 0.16081
# Epoch 150/5000
#
# Epoch 00150: val_loss did not improve from 0.16081
# Epoch 151/5000
#
# Epoch 00151: val_loss did not improve from 0.16081
# Epoch 152/5000
#
# Epoch 00152: val_loss did not improve from 0.16081
# Epoch 153/5000
#
# Epoch 00153: val_loss did not improve from 0.16081
# Epoch 154/5000
#
# Epoch 00154: val_loss did not improve from 0.16081
# Epoch 155/5000
#
# Epoch 00155: val_loss did not improve from 0.16081
# Epoch 156/5000
#
# Epoch 00156: val_loss did not improve from 0.16081
# Epoch 157/5000
#
# Epoch 00157: val_loss did not improve from 0.16081
# Epoch 158/5000
#
# Epoch 00158: val_loss did not improve from 0.16081
# Epoch 159/5000
#
# Epoch 00159: val_loss did not improve from 0.16081
# Epoch 160/5000
#
# Epoch 00160: val_loss did not improve from 0.16081
# Epoch 161/5000
#
# Epoch 00161: val_loss did not improve from 0.16081
# Epoch 162/5000
#
# Epoch 00162: val_loss did not improve from 0.16081
# Epoch 163/5000
#
# Epoch 00163: val_loss did not improve from 0.16081
# Epoch 164/5000
#
# Epoch 00164: val_loss did not improve from 0.16081
# Epoch 165/5000
#
# Epoch 00165: val_loss did not improve from 0.16081
# Epoch 166/5000
#
# Epoch 00166: val_loss did not improve from 0.16081
# Epoch 167/5000
#
# Epoch 00167: val_loss did not improve from 0.16081
# Epoch 168/5000
#
# Epoch 00168: val_loss did not improve from 0.16081
# Epoch 169/5000
#
# Epoch 00169: val_loss did not improve from 0.16081
# Epoch 170/5000
#
# Epoch 00170: val_loss did not improve from 0.16081
# Epoch 171/5000
#
# Epoch 00171: val_loss did not improve from 0.16081
# Epoch 172/5000
#
# Epoch 00172: val_loss did not improve from 0.16081
# Epoch 173/5000
#
# Epoch 00173: val_loss did not improve from 0.16081
# Epoch 174/5000
#
# Epoch 00174: val_loss did not improve from 0.16081
# Epoch 175/5000
#
# Epoch 00175: val_loss did not improve from 0.16081
# Epoch 176/5000
#
# Epoch 00176: val_loss did not improve from 0.16081
# Epoch 177/5000
#
# Epoch 00177: val_loss did not improve from 0.16081
# Epoch 178/5000
#
# Epoch 00178: val_loss did not improve from 0.16081
# Epoch 179/5000
#
# Epoch 00179: val_loss did not improve from 0.16081
# Epoch 180/5000
#
# Epoch 00180: val_loss did not improve from 0.16081
# Epoch 181/5000
#
# Epoch 00181: val_loss did not improve from 0.16081
# Epoch 182/5000
#
# Epoch 00182: val_loss did not improve from 0.16081
# Epoch 183/5000
#
# Epoch 00183: val_loss did not improve from 0.16081
# Epoch 184/5000
#
# Epoch 00184: val_loss did not improve from 0.16081
# Epoch 185/5000
#
# Epoch 00185: val_loss did not improve from 0.16081
# Epoch 186/5000
#
# Epoch 00186: val_loss did not improve from 0.16081
# Epoch 187/5000
#
# Epoch 00187: val_loss did not improve from 0.16081
# Epoch 188/5000
#
# Epoch 00188: val_loss did not improve from 0.16081
# Epoch 189/5000
#
# Epoch 00189: val_loss did not improve from 0.16081
# Epoch 190/5000
#
# Epoch 00190: val_loss did not improve from 0.16081
# Epoch 191/5000
#
# Epoch 00191: val_loss did not improve from 0.16081
# Epoch 192/5000
#
# Epoch 00192: val_loss did not improve from 0.16081
# Epoch 193/5000
#
# Epoch 00193: val_loss did not improve from 0.16081
# Epoch 194/5000
#
# Epoch 00194: val_loss did not improve from 0.16081
# Epoch 195/5000
#
# Epoch 00195: val_loss did not improve from 0.16081
# Epoch 196/5000
#
# Epoch 00196: val_loss did not improve from 0.16081
# Epoch 197/5000
#
# Epoch 00197: val_loss did not improve from 0.16081
# Epoch 198/5000
#
# Epoch 00198: val_loss did not improve from 0.16081
# Epoch 199/5000
#
# Epoch 00199: val_loss did not improve from 0.16081
# Epoch 200/5000
#
# Epoch 00200: val_loss did not improve from 0.16081
# Epoch 201/5000
#
# Epoch 00201: val_loss did not improve from 0.16081
# Epoch 202/5000
#
# Epoch 00202: val_loss did not improve from 0.16081
# Epoch 203/5000
#
# Epoch 00203: val_loss did not improve from 0.16081
# Epoch 204/5000
#
# Epoch 00204: val_loss did not improve from 0.16081
# Epoch 205/5000
#
# Epoch 00205: val_loss did not improve from 0.16081
# Epoch 206/5000
#
# Epoch 00206: val_loss did not improve from 0.16081
# Epoch 207/5000
#
# Epoch 00207: val_loss did not improve from 0.16081
# Epoch 208/5000
#
# Epoch 00208: val_loss did not improve from 0.16081
# Epoch 209/5000
#
# Epoch 00209: val_loss did not improve from 0.16081
# Epoch 210/5000
#
# Epoch 00210: val_loss did not improve from 0.16081
# Epoch 211/5000
#
# Epoch 00211: val_loss did not improve from 0.16081
# Epoch 212/5000
#
# Epoch 00212: val_loss did not improve from 0.16081
# Epoch 213/5000
#
# Epoch 00213: val_loss did not improve from 0.16081
# Epoch 214/5000
#
# Epoch 00214: val_loss did not improve from 0.16081
# Epoch 215/5000
#
# Epoch 00215: val_loss did not improve from 0.16081
# Epoch 216/5000
#
# Epoch 00216: val_loss did not improve from 0.16081
# Epoch 217/5000
#
# Epoch 00217: val_loss did not improve from 0.16081
# Epoch 218/5000
#
# Epoch 00218: val_loss did not improve from 0.16081
# Epoch 219/5000
#
# Epoch 00219: val_loss did not improve from 0.16081
# Epoch 220/5000
#
# Epoch 00220: val_loss did not improve from 0.16081
# Epoch 221/5000
#
# Epoch 00221: val_loss did not improve from 0.16081
# Epoch 222/5000
#
# Epoch 00222: val_loss did not improve from 0.16081
# Epoch 223/5000
#
# Epoch 00223: val_loss did not improve from 0.16081
# Epoch 224/5000
# Epoch 00224: val_loss did not improve from 0.16081
# Epoch 225/5000
#
# Epoch 00225: val_loss did not improve from 0.16081
# Epoch 226/5000
#
# Epoch 00226: val_loss did not improve from 0.16081
# Epoch 227/5000
#
# Epoch 00227: val_loss did not improve from 0.16081
# Epoch 228/5000
#
# Epoch 00228: val_loss did not improve from 0.16081
# Epoch 229/5000
#
# Epoch 00229: val_loss did not improve from 0.16081
# Epoch 230/5000
#
# Epoch 00230: val_loss did not improve from 0.16081
# Epoch 231/5000
#
# Epoch 00231: val_loss did not improve from 0.16081
# Epoch 232/5000
#
# Epoch 00232: val_loss did not improve from 0.16081
# Epoch 233/5000
#
# Epoch 00233: val_loss did not improve from 0.16081
# Epoch 234/5000
#
# Epoch 00234: val_loss did not improve from 0.16081
# Epoch 235/5000
#
# Epoch 00235: val_loss did not improve from 0.16081
# Epoch 236/5000
#
# Epoch 00236: val_loss did not improve from 0.16081
# Epoch 237/5000
#
# Epoch 00237: val_loss did not improve from 0.16081
# Epoch 238/5000
#
# Epoch 00238: val_loss did not improve from 0.16081
# Epoch 239/5000
#
# Epoch 00239: val_loss did not improve from 0.16081
# Epoch 240/5000
#
# Epoch 00240: val_loss did not improve from 0.16081
# Epoch 241/5000
#
# Epoch 00241: val_loss did not improve from 0.16081
# Epoch 242/5000
#
# Epoch 00242: val_loss did not improve from 0.16081
# Epoch 243/5000
#
# Epoch 00243: val_loss did not improve from 0.16081
# Epoch 244/5000
#
# Epoch 00244: val_loss did not improve from 0.16081
# Epoch 245/5000
#
# Epoch 00245: val_loss did not improve from 0.16081
# Epoch 246/5000
#
# Epoch 00246: val_loss did not improve from 0.16081
# Epoch 247/5000
#
# Epoch 00247: val_loss did not improve from 0.16081
# Epoch 248/5000
#
# Epoch 00248: val_loss did not improve from 0.16081
# Epoch 249/5000
#
# Epoch 00249: val_loss did not improve from 0.16081
# Epoch 250/5000
#
# Epoch 00250: val_loss did not improve from 0.16081
# Epoch 251/5000
#
# Epoch 00251: val_loss did not improve from 0.16081
# Epoch 252/5000
#
# Epoch 00252: val_loss did not improve from 0.16081
# Epoch 253/5000
#
# Epoch 00253: val_loss did not improve from 0.16081
# Epoch 254/5000
#
# Epoch 00254: val_loss did not improve from 0.16081
# Epoch 255/5000
#
# Epoch 00255: val_loss did not improve from 0.16081
# Epoch 256/5000
#
# Epoch 00256: val_loss did not improve from 0.16081
# Epoch 257/5000
#
# Epoch 00257: val_loss did not improve from 0.16081
# Epoch 258/5000
#
# Epoch 00258: val_loss did not improve from 0.16081
# Epoch 259/5000
#
# Epoch 00259: val_loss did not improve from 0.16081
# Epoch 260/5000
#
# Epoch 00260: val_loss did not improve from 0.16081
# Epoch 261/5000
#
# Epoch 00261: val_loss did not improve from 0.16081
# Epoch 262/5000
#
# Epoch 00262: val_loss did not improve from 0.16081
# Epoch 263/5000
#
# Epoch 00263: val_loss did not improve from 0.16081
# Epoch 264/5000
#
# Epoch 00264: val_loss did not improve from 0.16081
# Epoch 265/5000
#
# Epoch 00265: val_loss did not improve from 0.16081
# Epoch 266/5000
#
# Epoch 00266: val_loss did not improve from 0.16081
# Epoch 267/5000
#
# Epoch 00267: val_loss did not improve from 0.16081
# Epoch 268/5000
#
# Epoch 00268: val_loss did not improve from 0.16081
# Epoch 269/5000
#
# Epoch 00269: val_loss did not improve from 0.16081
# Epoch 270/5000
#
# Epoch 00270: val_loss did not improve from 0.16081
# Epoch 271/5000
#
# Epoch 00271: val_loss did not improve from 0.16081
# Epoch 272/5000
#
# Epoch 00272: val_loss did not improve from 0.16081
# Epoch 273/5000
#
# Epoch 00273: val_loss did not improve from 0.16081
# Epoch 274/5000
#
# Epoch 00274: val_loss did not improve from 0.16081
# Epoch 275/5000
#
# Epoch 00275: val_loss did not improve from 0.16081
# Epoch 276/5000
#
# Epoch 00276: val_loss did not improve from 0.16081
# Epoch 277/5000
#
# Epoch 00277: val_loss did not improve from 0.16081
# Epoch 278/5000
#
# Epoch 00278: val_loss improved from 0.16081 to 0.15492, saving model to saved-model_mc.h5
# Epoch 279/5000
#
# Epoch 00279: val_loss did not improve from 0.15492
# Epoch 280/5000
#
# Epoch 00280: val_loss did not improve from 0.15492
# Epoch 281/5000
#
# Epoch 00281: val_loss did not improve from 0.15492
# Epoch 282/5000
#
# Epoch 00282: val_loss did not improve from 0.15492
# Epoch 283/5000
#
# Epoch 00283: val_loss did not improve from 0.15492
# Epoch 284/5000
#
# Epoch 00284: val_loss did not improve from 0.15492
# Epoch 285/5000
#
# Epoch 00285: val_loss did not improve from 0.15492
# Epoch 286/5000
#
# Epoch 00286: val_loss did not improve from 0.15492
# Epoch 287/5000
#
# Epoch 00287: val_loss did not improve from 0.15492
# Epoch 288/5000
#
# Epoch 00288: val_loss did not improve from 0.15492
# Epoch 289/5000
#
# Epoch 00289: val_loss did not improve from 0.15492
# Epoch 290/5000
#
# Epoch 00290: val_loss did not improve from 0.15492
# Epoch 291/5000
#
# Epoch 00291: val_loss did not improve from 0.15492
# Epoch 292/5000
#
# Epoch 00292: val_loss did not improve from 0.15492
# Epoch 293/5000
#
# Epoch 00293: val_loss did not improve from 0.15492
# Epoch 294/5000
#
# Epoch 00294: val_loss did not improve from 0.15492
# Epoch 295/5000
#
# Epoch 00295: val_loss did not improve from 0.15492
# Epoch 296/5000
#
# Epoch 00296: val_loss did not improve from 0.15492
# Epoch 297/5000
#
# Epoch 00297: val_loss did not improve from 0.15492
# Epoch 298/5000
#
# Epoch 00298: val_loss did not improve from 0.15492
# Epoch 299/5000
#
# Epoch 00299: val_loss did not improve from 0.15492
# Epoch 300/5000
#
# Epoch 00300: val_loss did not improve from 0.15492
# Epoch 301/5000
#
# Epoch 00301: val_loss did not improve from 0.15492
# Epoch 302/5000
#
# Epoch 00302: val_loss did not improve from 0.15492
# Epoch 303/5000
#
# Epoch 00303: val_loss did not improve from 0.15492
# Epoch 304/5000
#
# Epoch 00304: val_loss did not improve from 0.15492
# Epoch 305/5000
#
# Epoch 00305: val_loss did not improve from 0.15492
# Epoch 306/5000
#
# Epoch 00306: val_loss did not improve from 0.15492
# Epoch 307/5000
#
# Epoch 00307: val_loss did not improve from 0.15492
# Epoch 308/5000
#
# Epoch 00308: val_loss did not improve from 0.15492
# Epoch 309/5000
#
# Epoch 00309: val_loss did not improve from 0.15492
# Epoch 310/5000
#
# Epoch 00310: val_loss did not improve from 0.15492
# Epoch 311/5000
#
# Epoch 00311: val_loss did not improve from 0.15492
# Epoch 312/5000
#
# Epoch 00312: val_loss did not improve from 0.15492
# Epoch 313/5000
#
# Epoch 00313: val_loss did not improve from 0.15492
# Epoch 314/5000
#
# Epoch 00314: val_loss did not improve from 0.15492
# Epoch 315/5000
#
# Epoch 00315: val_loss did not improve from 0.15492
# Epoch 316/5000
#
# Epoch 00316: val_loss did not improve from 0.15492
# Epoch 317/5000
#
# Epoch 00317: val_loss did not improve from 0.15492
# Epoch 318/5000
#
# Epoch 00318: val_loss did not improve from 0.15492
# Epoch 319/5000
#
# Epoch 00319: val_loss did not improve from 0.15492
# Epoch 320/5000
#
# Epoch 00320: val_loss did not improve from 0.15492
# Epoch 321/5000
#
# Epoch 00321: val_loss did not improve from 0.15492
# Epoch 322/5000
#
# Epoch 00322: val_loss did not improve from 0.15492
# Epoch 323/5000
#
# Epoch 00323: val_loss did not improve from 0.15492
# Epoch 324/5000
#
# Epoch 00324: val_loss did not improve from 0.15492
# Epoch 325/5000
#
# Epoch 00325: val_loss did not improve from 0.15492
# Epoch 326/5000
#
# Epoch 00326: val_loss did not improve from 0.15492
# Epoch 327/5000
#
# Epoch 00327: val_loss did not improve from 0.15492
# Epoch 328/5000
#
# Epoch 00328: val_loss did not improve from 0.15492
# Epoch 329/5000
#
# Epoch 00329: val_loss did not improve from 0.15492
# Epoch 330/5000
#
# Epoch 00330: val_loss did not improve from 0.15492
# Epoch 331/5000
#
# Epoch 00331: val_loss did not improve from 0.15492
# Epoch 332/5000
#
# Epoch 00332: val_loss did not improve from 0.15492
# Epoch 333/5000
#
# Epoch 00333: val_loss did not improve from 0.15492
# Epoch 334/5000
#
# Epoch 00334: val_loss did not improve from 0.15492
# Epoch 335/5000
#
# Epoch 00335: val_loss did not improve from 0.15492
# Epoch 336/5000
#
# Epoch 00336: val_loss did not improve from 0.15492
# Epoch 337/5000
#
# Epoch 00337: val_loss did not improve from 0.15492
# Epoch 338/5000
#
# Epoch 00338: val_loss did not improve from 0.15492
# Epoch 339/5000
#
# Epoch 00339: val_loss did not improve from 0.15492
# Epoch 340/5000
#
# Epoch 00340: val_loss did not improve from 0.15492
# Epoch 341/5000
#
# Epoch 00341: val_loss did not improve from 0.15492
# Epoch 342/5000
#
# Epoch 00342: val_loss did not improve from 0.15492
# Epoch 343/5000
#
# Epoch 00343: val_loss did not improve from 0.15492
# Epoch 344/5000
#
# Epoch 00344: val_loss did not improve from 0.15492
# Epoch 345/5000
#
# Epoch 00345: val_loss did not improve from 0.15492
# Epoch 346/5000
#
# Epoch 00346: val_loss did not improve from 0.15492
# Epoch 347/5000
#
# Epoch 00347: val_loss did not improve from 0.15492
# Epoch 348/5000
#
# Epoch 00348: val_loss did not improve from 0.15492
# Epoch 349/5000
#
# Epoch 00349: val_loss did not improve from 0.15492
# Epoch 350/5000
#
# Epoch 00350: val_loss did not improve from 0.15492
# Epoch 351/5000
#
# Epoch 00351: val_loss did not improve from 0.15492
# Epoch 352/5000
#
# Epoch 00352: val_loss did not improve from 0.15492
# Epoch 353/5000
#
# Epoch 00353: val_loss did not improve from 0.15492
# Epoch 354/5000
#
# Epoch 00354: val_loss did not improve from 0.15492
# Epoch 355/5000
#
# Epoch 00355: val_loss did not improve from 0.15492
# Epoch 356/5000
#
# Epoch 00356: val_loss did not improve from 0.15492
# Epoch 357/5000
#
# Epoch 00357: val_loss did not improve from 0.15492
# Epoch 358/5000
#
# Epoch 00358: val_loss did not improve from 0.15492
# Epoch 359/5000
#
# Epoch 00359: val_loss did not improve from 0.15492
# Epoch 360/5000
#
# Epoch 00360: val_loss did not improve from 0.15492
# Epoch 361/5000
#
# Epoch 00361: val_loss did not improve from 0.15492
# Epoch 362/5000
#
# Epoch 00362: val_loss did not improve from 0.15492
# Epoch 363/5000
#
# Epoch 00363: val_loss did not improve from 0.15492
# Epoch 364/5000
#
# Epoch 00364: val_loss did not improve from 0.15492
# Epoch 365/5000
#
# Epoch 00365: val_loss did not improve from 0.15492
# Epoch 366/5000
#
# Epoch 00366: val_loss improved from 0.15492 to 0.15147, saving model to saved-model_mc.h5
# Epoch 367/5000
#
# Epoch 00367: val_loss did not improve from 0.15147
# Epoch 368/5000
#
# Epoch 00368: val_loss did not improve from 0.15147
# Epoch 369/5000
#
# Epoch 00369: val_loss did not improve from 0.15147
# Epoch 370/5000
#
# Epoch 00370: val_loss did not improve from 0.15147
# Epoch 371/5000
#
# Epoch 00371: val_loss did not improve from 0.15147
# Epoch 372/5000
#
# Epoch 00372: val_loss did not improve from 0.15147
# Epoch 373/5000
#
# Epoch 00373: val_loss did not improve from 0.15147
# Epoch 374/5000
#
# Epoch 00374: val_loss did not improve from 0.15147
# Epoch 375/5000
#
# Epoch 00375: val_loss improved from 0.15147 to 0.14586, saving model to saved-model_mc.h5
# Epoch 376/5000
#
# Epoch 00376: val_loss did not improve from 0.14586
# Epoch 377/5000
#
# Epoch 00377: val_loss did not improve from 0.14586
# Epoch 378/5000
#
# Epoch 00378: val_loss did not improve from 0.14586
# Epoch 379/5000
#
# Epoch 00379: val_loss did not improve from 0.14586
# Epoch 380/5000
#
# Epoch 00380: val_loss did not improve from 0.14586
# Epoch 381/5000
#
# Epoch 00381: val_loss did not improve from 0.14586
# Epoch 382/5000
#
# Epoch 00382: val_loss did not improve from 0.14586
# Epoch 383/5000
#
# Epoch 00383: val_loss did not improve from 0.14586
# Epoch 384/5000
#
# Epoch 00384: val_loss did not improve from 0.14586
# Epoch 385/5000
#
# Epoch 00385: val_loss did not improve from 0.14586
# Epoch 386/5000
#
# Epoch 00386: val_loss did not improve from 0.14586
# Epoch 387/5000
#
# Epoch 00387: val_loss did not improve from 0.14586
# Epoch 388/5000
#
# Epoch 00388: val_loss did not improve from 0.14586
# Epoch 389/5000
#
# Epoch 00389: val_loss did not improve from 0.14586
# Epoch 390/5000
#
# Epoch 00390: val_loss did not improve from 0.14586
# Epoch 391/5000
#
# Epoch 00391: val_loss did not improve from 0.14586
# Epoch 392/5000
#
# Epoch 00392: val_loss did not improve from 0.14586
# Epoch 393/5000
#
# Epoch 00393: val_loss did not improve from 0.14586
# Epoch 394/5000
#
# Epoch 00394: val_loss did not improve from 0.14586
# Epoch 395/5000
#
# Epoch 00395: val_loss did not improve from 0.14586
# Epoch 396/5000
#
# Epoch 00396: val_loss did not improve from 0.14586
# Epoch 397/5000
#
# Epoch 00397: val_loss did not improve from 0.14586
# Epoch 398/5000
#
# Epoch 00398: val_loss did not improve from 0.14586
# Epoch 399/5000
#
# Epoch 00399: val_loss did not improve from 0.14586
# Epoch 400/5000
#
# Epoch 00400: val_loss did not improve from 0.14586
# Epoch 401/5000
#
# Epoch 00401: val_loss did not improve from 0.14586
# Epoch 402/5000
#
# Epoch 00402: val_loss did not improve from 0.14586
# Epoch 403/5000
#
# Epoch 00403: val_loss did not improve from 0.14586
# Epoch 404/5000
#
# Epoch 00404: val_loss did not improve from 0.14586
# Epoch 405/5000
#
# Epoch 00405: val_loss did not improve from 0.14586
# Epoch 406/5000
#
# Epoch 00406: val_loss did not improve from 0.14586
# Epoch 407/5000
#
# Epoch 00407: val_loss did not improve from 0.14586
# Epoch 408/5000
#
# Epoch 00408: val_loss did not improve from 0.14586
# Epoch 409/5000
#
# Epoch 00409: val_loss did not improve from 0.14586
# Epoch 410/5000
#
# Epoch 00410: val_loss did not improve from 0.14586
# Epoch 411/5000
#
# Epoch 00411: val_loss did not improve from 0.14586
# Epoch 412/5000
#
# Epoch 00412: val_loss did not improve from 0.14586
# Epoch 413/5000
#
# Epoch 00413: val_loss did not improve from 0.14586
# Epoch 414/5000
#
# Epoch 00414: val_loss did not improve from 0.14586
# Epoch 415/5000
#
# Epoch 00415: val_loss did not improve from 0.14586
# Epoch 416/5000
#
# Epoch 00416: val_loss did not improve from 0.14586
# Epoch 417/5000
#
# Epoch 00417: val_loss did not improve from 0.14586
# Epoch 418/5000
#
# Epoch 00418: val_loss did not improve from 0.14586
# Epoch 419/5000
#
# Epoch 00419: val_loss did not improve from 0.14586
# Epoch 420/5000
#
# Epoch 00420: val_loss did not improve from 0.14586
# Epoch 421/5000
#
# Epoch 00421: val_loss did not improve from 0.14586
# Epoch 422/5000
#
# Epoch 00422: val_loss did not improve from 0.14586
# Epoch 423/5000
#
# Epoch 00423: val_loss did not improve from 0.14586
# Epoch 424/5000
#
# Epoch 00424: val_loss did not improve from 0.14586
# Epoch 425/5000
#
# Epoch 00425: val_loss did not improve from 0.14586
# Epoch 426/5000
#
# Epoch 00426: val_loss did not improve from 0.14586
# Epoch 427/5000
#
# Epoch 00427: val_loss did not improve from 0.14586
# Epoch 428/5000
#
# Epoch 00428: val_loss did not improve from 0.14586
# Epoch 429/5000
#
# Epoch 00429: val_loss did not improve from 0.14586
# Epoch 430/5000
#
# Epoch 00430: val_loss did not improve from 0.14586
# Epoch 431/5000
#
# Epoch 00431: val_loss did not improve from 0.14586
# Epoch 432/5000
#
# Epoch 00432: val_loss did not improve from 0.14586
# Epoch 433/5000
#
# Epoch 00433: val_loss did not improve from 0.14586
# Epoch 434/5000
#
# Epoch 00434: val_loss did not improve from 0.14586
# Epoch 435/5000
#
# Epoch 00435: val_loss did not improve from 0.14586
# Epoch 436/5000
#
# Epoch 00436: val_loss did not improve from 0.14586
# Epoch 437/5000
#
# Epoch 00437: val_loss did not improve from 0.14586
# Epoch 438/5000
#
# Epoch 00438: val_loss did not improve from 0.14586
# Epoch 439/5000
#
# Epoch 00439: val_loss did not improve from 0.14586
# Epoch 440/5000
#
# Epoch 00440: val_loss did not improve from 0.14586
# Epoch 441/5000
#
# Epoch 00441: val_loss did not improve from 0.14586
# Epoch 442/5000
#
# Epoch 00442: val_loss did not improve from 0.14586
# Epoch 443/5000
#
# Epoch 00443: val_loss did not improve from 0.14586
# Epoch 444/5000
#
# Epoch 00444: val_loss did not improve from 0.14586
# Epoch 445/5000
#
# Epoch 00445: val_loss did not improve from 0.14586
# Epoch 446/5000
#
# Epoch 00446: val_loss did not improve from 0.14586
# Epoch 447/5000
#
# Epoch 00447: val_loss did not improve from 0.14586
# Epoch 448/5000
#
# Epoch 00448: val_loss did not improve from 0.14586
# Epoch 449/5000
#
# Epoch 00449: val_loss did not improve from 0.14586
# Epoch 450/5000
#
# Epoch 00450: val_loss did not improve from 0.14586
# Epoch 451/5000
#
# Epoch 00451: val_loss did not improve from 0.14586
# Epoch 452/5000
#
# Epoch 00452: val_loss did not improve from 0.14586
# Epoch 453/5000
#
# Epoch 00453: val_loss did not improve from 0.14586
# Epoch 454/5000
#
# Epoch 00454: val_loss did not improve from 0.14586
# Epoch 455/5000
#
# Epoch 00455: val_loss did not improve from 0.14586
# Epoch 456/5000
#
# Epoch 00456: val_loss did not improve from 0.14586
# Epoch 457/5000
#
# Epoch 00457: val_loss did not improve from 0.14586
# Epoch 458/5000
#
# Epoch 00458: val_loss did not improve from 0.14586
# Epoch 459/5000
#
# Epoch 00459: val_loss did not improve from 0.14586
# Epoch 460/5000
#
# Epoch 00460: val_loss did not improve from 0.14586
# Epoch 461/5000
#
# Epoch 00461: val_loss did not improve from 0.14586
# Epoch 462/5000
#
# Epoch 00462: val_loss did not improve from 0.14586
# Epoch 463/5000
#
# Epoch 00463: val_loss did not improve from 0.14586
# Epoch 464/5000
#
# Epoch 00464: val_loss did not improve from 0.14586
# Epoch 465/5000
#
# Epoch 00465: val_loss did not improve from 0.14586
# Epoch 466/5000
# Epoch 00466: val_loss did not improve from 0.14586
# Epoch 467/5000
#
# Epoch 00467: val_loss did not improve from 0.14586
# Epoch 468/5000
#
# Epoch 00468: val_loss did not improve from 0.14586
# Epoch 469/5000
#
# Epoch 00469: val_loss did not improve from 0.14586
# Epoch 470/5000
#
# Epoch 00470: val_loss did not improve from 0.14586
# Epoch 471/5000
#
# Epoch 00471: val_loss did not improve from 0.14586
# Epoch 472/5000
#
# Epoch 00472: val_loss did not improve from 0.14586
# Epoch 473/5000
#
# Epoch 00473: val_loss did not improve from 0.14586
# Epoch 474/5000
#
# Epoch 00474: val_loss did not improve from 0.14586
# Epoch 475/5000
#
# Epoch 00475: val_loss did not improve from 0.14586
# Epoch 476/5000
#
# Epoch 00476: val_loss did not improve from 0.14586
# Epoch 477/5000
#
# Epoch 00477: val_loss did not improve from 0.14586
# Epoch 478/5000
#
# Epoch 00478: val_loss did not improve from 0.14586
# Epoch 479/5000
#
# Epoch 00479: val_loss did not improve from 0.14586
# Epoch 480/5000
#
# Epoch 00480: val_loss did not improve from 0.14586
# Epoch 481/5000
#
# Epoch 00481: val_loss did not improve from 0.14586
# Epoch 482/5000
#
# Epoch 00482: val_loss did not improve from 0.14586
# Epoch 483/5000
#
# Epoch 00483: val_loss did not improve from 0.14586
# Epoch 484/5000
#
# Epoch 00484: val_loss did not improve from 0.14586
# Epoch 485/5000
#
# Epoch 00485: val_loss did not improve from 0.14586
# Epoch 486/5000
#
# Epoch 00486: val_loss did not improve from 0.14586
# Epoch 487/5000
#
# Epoch 00487: val_loss did not improve from 0.14586
# Epoch 488/5000
#
# Epoch 00488: val_loss did not improve from 0.14586
# Epoch 489/5000
#
# Epoch 00489: val_loss did not improve from 0.14586
# Epoch 490/5000
#
# Epoch 00490: val_loss did not improve from 0.14586
# Epoch 491/5000
#
# Epoch 00491: val_loss did not improve from 0.14586
# Epoch 492/5000
#
# Epoch 00492: val_loss did not improve from 0.14586
# Epoch 493/5000
#
# Epoch 00493: val_loss did not improve from 0.14586
# Epoch 494/5000
#
# Epoch 00494: val_loss did not improve from 0.14586
# Epoch 495/5000
#
# Epoch 00495: val_loss did not improve from 0.14586
# Epoch 496/5000
#
# Epoch 00496: val_loss did not improve from 0.14586
# Epoch 497/5000
#
# Epoch 00497: val_loss did not improve from 0.14586
# Epoch 498/5000
#
# Epoch 00498: val_loss did not improve from 0.14586
# Epoch 499/5000
#
# Epoch 00499: val_loss did not improve from 0.14586
# Epoch 500/5000
#
# Epoch 00500: val_loss did not improve from 0.14586
# Epoch 501/5000
#
# Epoch 00501: val_loss did not improve from 0.14586
# Epoch 502/5000
#
# Epoch 00502: val_loss did not improve from 0.14586
# Epoch 503/5000
#
# Epoch 00503: val_loss did not improve from 0.14586
# Epoch 504/5000
#
# Epoch 00504: val_loss did not improve from 0.14586
# Epoch 505/5000
#
# Epoch 00505: val_loss did not improve from 0.14586
# Epoch 506/5000
#
# Epoch 00506: val_loss did not improve from 0.14586
# Epoch 507/5000
#
# Epoch 00507: val_loss did not improve from 0.14586
# Epoch 508/5000
#
# Epoch 00508: val_loss did not improve from 0.14586
# Epoch 509/5000
#
# Epoch 00509: val_loss did not improve from 0.14586
# Epoch 510/5000
#
# Epoch 00510: val_loss did not improve from 0.14586
# Epoch 511/5000
#
# Epoch 00511: val_loss did not improve from 0.14586
# Epoch 512/5000
#
# Epoch 00512: val_loss did not improve from 0.14586
# Epoch 513/5000
#
# Epoch 00513: val_loss did not improve from 0.14586
# Epoch 514/5000
#
# Epoch 00514: val_loss did not improve from 0.14586
# Epoch 515/5000
#
# Epoch 00515: val_loss did not improve from 0.14586
# Epoch 516/5000
#
# Epoch 00516: val_loss did not improve from 0.14586
# Epoch 517/5000
#
# Epoch 00517: val_loss did not improve from 0.14586
# Epoch 518/5000
#
# Epoch 00518: val_loss did not improve from 0.14586
# Epoch 519/5000
#
# Epoch 00519: val_loss did not improve from 0.14586
# Epoch 520/5000
#
# Epoch 00520: val_loss did not improve from 0.14586
# Epoch 521/5000
#
# Epoch 00521: val_loss did not improve from 0.14586
# Epoch 522/5000
#
# Epoch 00522: val_loss did not improve from 0.14586
# Epoch 523/5000
#
# Epoch 00523: val_loss did not improve from 0.14586
# Epoch 524/5000
#
# Epoch 00524: val_loss did not improve from 0.14586
# Epoch 525/5000
#
# Epoch 00525: val_loss did not improve from 0.14586
# Epoch 526/5000
#
# Epoch 00526: val_loss did not improve from 0.14586
# Epoch 527/5000
#
# Epoch 00527: val_loss did not improve from 0.14586
# Epoch 528/5000
#
# Epoch 00528: val_loss did not improve from 0.14586
# Epoch 529/5000
#
# Epoch 00529: val_loss did not improve from 0.14586
# Epoch 530/5000
#
# Epoch 00530: val_loss did not improve from 0.14586
# Epoch 531/5000
#
# Epoch 00531: val_loss did not improve from 0.14586
# Epoch 532/5000
#
# Epoch 00532: val_loss did not improve from 0.14586
# Epoch 533/5000
#
# Epoch 00533: val_loss did not improve from 0.14586
# Epoch 534/5000
#
# Epoch 00534: val_loss did not improve from 0.14586
# Epoch 535/5000
#
# Epoch 00535: val_loss did not improve from 0.14586
# Epoch 536/5000
#
# Epoch 00536: val_loss did not improve from 0.14586
# Epoch 537/5000
#
# Epoch 00537: val_loss did not improve from 0.14586
# Epoch 538/5000
#
# Epoch 00538: val_loss did not improve from 0.14586
# Epoch 539/5000
#
# Epoch 00539: val_loss did not improve from 0.14586
# Epoch 540/5000
#
# Epoch 00540: val_loss did not improve from 0.14586
# Epoch 541/5000
#
# Epoch 00541: val_loss did not improve from 0.14586
# Epoch 542/5000
#
# Epoch 00542: val_loss did not improve from 0.14586
# Epoch 543/5000
#
# Epoch 00543: val_loss did not improve from 0.14586
# Epoch 544/5000
#
# Epoch 00544: val_loss did not improve from 0.14586
# Epoch 545/5000
#
# Epoch 00545: val_loss did not improve from 0.14586
# Epoch 546/5000
#
# Epoch 00546: val_loss did not improve from 0.14586
# Epoch 547/5000
#
# Epoch 00547: val_loss did not improve from 0.14586
# Epoch 548/5000
#
# Epoch 00548: val_loss did not improve from 0.14586
# Epoch 549/5000
#
# Epoch 00549: val_loss did not improve from 0.14586
# Epoch 550/5000
#
# Epoch 00550: val_loss did not improve from 0.14586
# Epoch 551/5000
#
# Epoch 00551: val_loss did not improve from 0.14586
# Epoch 552/5000
#
# Epoch 00552: val_loss did not improve from 0.14586
# Epoch 553/5000
#
# Epoch 00553: val_loss did not improve from 0.14586
# Epoch 554/5000
#
# Epoch 00554: val_loss did not improve from 0.14586
# Epoch 555/5000
#
# Epoch 00555: val_loss did not improve from 0.14586
# Epoch 556/5000
#
# Epoch 00556: val_loss did not improve from 0.14586
# Epoch 557/5000
#
# Epoch 00557: val_loss did not improve from 0.14586
# Epoch 558/5000
#
# Epoch 00558: val_loss did not improve from 0.14586
# Epoch 559/5000
#
# Epoch 00559: val_loss did not improve from 0.14586
# Epoch 560/5000
#
# Epoch 00560: val_loss did not improve from 0.14586
# Epoch 561/5000
#
# Epoch 00561: val_loss did not improve from 0.14586
# Epoch 562/5000
#
# Epoch 00562: val_loss did not improve from 0.14586
# Epoch 563/5000
#
# Epoch 00563: val_loss did not improve from 0.14586
# Epoch 564/5000
#
# Epoch 00564: val_loss did not improve from 0.14586
# Epoch 565/5000
#
# Epoch 00565: val_loss did not improve from 0.14586
# Epoch 566/5000
#
# Epoch 00566: val_loss did not improve from 0.14586
# Epoch 567/5000
#
# Epoch 00567: val_loss did not improve from 0.14586
# Epoch 568/5000
#
# Epoch 00568: val_loss did not improve from 0.14586
# Epoch 569/5000
#
# Epoch 00569: val_loss did not improve from 0.14586
# Epoch 570/5000
#
# Epoch 00570: val_loss did not improve from 0.14586
# Epoch 571/5000
#
# Epoch 00571: val_loss did not improve from 0.14586
# Epoch 572/5000
#
# Epoch 00572: val_loss did not improve from 0.14586
# Epoch 573/5000
#
# Epoch 00573: val_loss improved from 0.14586 to 0.14501, saving model to saved-model_mc.h5
# Epoch 574/5000
#
# Epoch 00574: val_loss did not improve from 0.14501
# Epoch 575/5000
#
# Epoch 00575: val_loss did not improve from 0.14501
# Epoch 576/5000
#
# Epoch 00576: val_loss did not improve from 0.14501
# Epoch 577/5000
#
# Epoch 00577: val_loss did not improve from 0.14501
# Epoch 578/5000
#
# Epoch 00578: val_loss did not improve from 0.14501
# Epoch 579/5000
#
# Epoch 00579: val_loss did not improve from 0.14501
# Epoch 580/5000
#
# Epoch 00580: val_loss did not improve from 0.14501
# Epoch 581/5000
#
# Epoch 00581: val_loss did not improve from 0.14501
# Epoch 582/5000
#
# Epoch 00582: val_loss did not improve from 0.14501
# Epoch 583/5000
#
# Epoch 00583: val_loss did not improve from 0.14501
# Epoch 584/5000
#
# Epoch 00584: val_loss did not improve from 0.14501
# Epoch 585/5000
#
# Epoch 00585: val_loss did not improve from 0.14501
# Epoch 586/5000
#
# Epoch 00586: val_loss did not improve from 0.14501
# Epoch 587/5000
#
# Epoch 00587: val_loss did not improve from 0.14501
# Epoch 588/5000
#
# Epoch 00588: val_loss did not improve from 0.14501
# Epoch 589/5000
#
# Epoch 00589: val_loss did not improve from 0.14501
# Epoch 590/5000
#
# Epoch 00590: val_loss did not improve from 0.14501
# Epoch 591/5000
#
# Epoch 00591: val_loss did not improve from 0.14501
# Epoch 592/5000
#
# Epoch 00592: val_loss did not improve from 0.14501
# Epoch 593/5000
#
# Epoch 00593: val_loss did not improve from 0.14501
# Epoch 594/5000
#
# Epoch 00594: val_loss did not improve from 0.14501
# Epoch 595/5000
#
# Epoch 00595: val_loss did not improve from 0.14501
# Epoch 596/5000
#
# Epoch 00596: val_loss did not improve from 0.14501
# Epoch 597/5000
#
# Epoch 00597: val_loss did not improve from 0.14501
# Epoch 598/5000
#
# Epoch 00598: val_loss did not improve from 0.14501
# Epoch 599/5000
#
# Epoch 00599: val_loss did not improve from 0.14501
# Epoch 600/5000
#
# Epoch 00600: val_loss did not improve from 0.14501
# Epoch 601/5000
#
# Epoch 00601: val_loss did not improve from 0.14501
# Epoch 602/5000
#
# Epoch 00602: val_loss did not improve from 0.14501
# Epoch 603/5000
#
# Epoch 00603: val_loss did not improve from 0.14501
# Epoch 604/5000
#
# Epoch 00604: val_loss did not improve from 0.14501
# Epoch 605/5000
#
# Epoch 00605: val_loss did not improve from 0.14501
# Epoch 606/5000
#
# Epoch 00606: val_loss did not improve from 0.14501
# Epoch 607/5000
#
# Epoch 00607: val_loss did not improve from 0.14501
# Epoch 608/5000
#
# Epoch 00608: val_loss did not improve from 0.14501
# Epoch 609/5000
#
# Epoch 00609: val_loss did not improve from 0.14501
# Epoch 610/5000
#
# Epoch 00610: val_loss did not improve from 0.14501
# Epoch 611/5000
#
# Epoch 00611: val_loss did not improve from 0.14501
# Epoch 612/5000
#
# Epoch 00612: val_loss did not improve from 0.14501
# Epoch 613/5000
#
# Epoch 00613: val_loss did not improve from 0.14501
# Epoch 614/5000
#
# Epoch 00614: val_loss did not improve from 0.14501
# Epoch 615/5000
#
# Epoch 00615: val_loss did not improve from 0.14501
# Epoch 616/5000
#
# Epoch 00616: val_loss did not improve from 0.14501
# Epoch 617/5000
#
# Epoch 00617: val_loss did not improve from 0.14501
# Epoch 618/5000
#
# Epoch 00618: val_loss did not improve from 0.14501
# Epoch 619/5000
#
# Epoch 00619: val_loss did not improve from 0.14501
# Epoch 620/5000
#
# Epoch 00620: val_loss did not improve from 0.14501
# Epoch 621/5000
#
# Epoch 00621: val_loss did not improve from 0.14501
# Epoch 622/5000
#
# Epoch 00622: val_loss did not improve from 0.14501
# Epoch 623/5000
#
# Epoch 00623: val_loss did not improve from 0.14501
# Epoch 624/5000
#
# Epoch 00624: val_loss did not improve from 0.14501
# Epoch 625/5000
#
# Epoch 00625: val_loss did not improve from 0.14501
# Epoch 626/5000
#
# Epoch 00626: val_loss did not improve from 0.14501
# Epoch 627/5000
#
# Epoch 00627: val_loss did not improve from 0.14501
# Epoch 628/5000
#
# Epoch 00628: val_loss did not improve from 0.14501
# Epoch 629/5000
#
# Epoch 00629: val_loss did not improve from 0.14501
# Epoch 630/5000
#
# Epoch 00630: val_loss improved from 0.14501 to 0.14093, saving model to saved-model_mc.h5
# Epoch 631/5000
#
# Epoch 00631: val_loss did not improve from 0.14093
# Epoch 632/5000
#
# Epoch 00632: val_loss did not improve from 0.14093
# Epoch 633/5000
#
# Epoch 00633: val_loss did not improve from 0.14093
# Epoch 634/5000
#
# Epoch 00634: val_loss did not improve from 0.14093
# Epoch 635/5000
#
# Epoch 00635: val_loss did not improve from 0.14093
# Epoch 636/5000
#
# Epoch 00636: val_loss did not improve from 0.14093
# Epoch 637/5000
#
# Epoch 00637: val_loss did not improve from 0.14093
# Epoch 638/5000
#
# Epoch 00638: val_loss did not improve from 0.14093
# Epoch 639/5000
#
# Epoch 00639: val_loss did not improve from 0.14093
# Epoch 640/5000
#
# Epoch 00640: val_loss did not improve from 0.14093
# Epoch 641/5000
#
# Epoch 00641: val_loss did not improve from 0.14093
# Epoch 642/5000
#
# Epoch 00642: val_loss did not improve from 0.14093
# Epoch 643/5000
#
# Epoch 00643: val_loss did not improve from 0.14093
# Epoch 644/5000
#
# Epoch 00644: val_loss did not improve from 0.14093
# Epoch 645/5000
#
# Epoch 00645: val_loss did not improve from 0.14093
# Epoch 646/5000
#
# Epoch 00646: val_loss did not improve from 0.14093
# Epoch 647/5000
#
# Epoch 00647: val_loss did not improve from 0.14093
# Epoch 648/5000
#
# Epoch 00648: val_loss did not improve from 0.14093
# Epoch 649/5000
#
# Epoch 00649: val_loss did not improve from 0.14093
# Epoch 650/5000
#
# Epoch 00650: val_loss did not improve from 0.14093
# Epoch 651/5000
#
# Epoch 00651: val_loss did not improve from 0.14093
# Epoch 652/5000
#
# Epoch 00652: val_loss did not improve from 0.14093
# Epoch 653/5000
#
# Epoch 00653: val_loss did not improve from 0.14093
# Epoch 654/5000
#
# Epoch 00654: val_loss did not improve from 0.14093
# Epoch 655/5000
#
# Epoch 00655: val_loss did not improve from 0.14093
# Epoch 656/5000
#
# Epoch 00656: val_loss did not improve from 0.14093
# Epoch 657/5000
#
# Epoch 00657: val_loss did not improve from 0.14093
# Epoch 658/5000
#
# Epoch 00658: val_loss did not improve from 0.14093
# Epoch 659/5000
#
# Epoch 00659: val_loss did not improve from 0.14093
# Epoch 660/5000
#
# Epoch 00660: val_loss did not improve from 0.14093
# Epoch 661/5000
#
# Epoch 00661: val_loss did not improve from 0.14093
# Epoch 662/5000
#
# Epoch 00662: val_loss did not improve from 0.14093
# Epoch 663/5000
#
# Epoch 00663: val_loss did not improve from 0.14093
# Epoch 664/5000
#
# Epoch 00664: val_loss did not improve from 0.14093
# Epoch 665/5000
#
# Epoch 00665: val_loss did not improve from 0.14093
# Epoch 666/5000
#
# Epoch 00666: val_loss did not improve from 0.14093
# Epoch 667/5000
#
# Epoch 00667: val_loss did not improve from 0.14093
# Epoch 668/5000
#
# Epoch 00668: val_loss did not improve from 0.14093
# Epoch 669/5000
#
# Epoch 00669: val_loss did not improve from 0.14093
# Epoch 670/5000
#
# Epoch 00670: val_loss did not improve from 0.14093
# Epoch 671/5000
#
# Epoch 00671: val_loss did not improve from 0.14093
# Epoch 672/5000
#
# Epoch 00672: val_loss did not improve from 0.14093
# Epoch 673/5000
#
# Epoch 00673: val_loss did not improve from 0.14093
# Epoch 674/5000
#
# Epoch 00674: val_loss did not improve from 0.14093
# Epoch 675/5000
#
# Epoch 00675: val_loss did not improve from 0.14093
# Epoch 676/5000
#
# Epoch 00676: val_loss did not improve from 0.14093
# Epoch 677/5000
#
# Epoch 00677: val_loss did not improve from 0.14093
# Epoch 678/5000
#
# Epoch 00678: val_loss did not improve from 0.14093
# Epoch 679/5000
#
# Epoch 00679: val_loss did not improve from 0.14093
# Epoch 680/5000
#
# Epoch 00680: val_loss did not improve from 0.14093
# Epoch 681/5000
#
# Epoch 00681: val_loss did not improve from 0.14093
# Epoch 682/5000
#
# Epoch 00682: val_loss did not improve from 0.14093
# Epoch 683/5000
#
# Epoch 00683: val_loss did not improve from 0.14093
# Epoch 684/5000
#
# Epoch 00684: val_loss did not improve from 0.14093
# Epoch 685/5000
#
# Epoch 00685: val_loss did not improve from 0.14093
# Epoch 686/5000
#
# Epoch 00686: val_loss did not improve from 0.14093
# Epoch 687/5000
#
# Epoch 00687: val_loss did not improve from 0.14093
# Epoch 688/5000
#
# Epoch 00688: val_loss did not improve from 0.14093
# Epoch 689/5000
#
# Epoch 00689: val_loss did not improve from 0.14093
# Epoch 690/5000
#
# Epoch 00690: val_loss did not improve from 0.14093
# Epoch 691/5000
#
# Epoch 00691: val_loss did not improve from 0.14093
# Epoch 692/5000
#
# Epoch 00692: val_loss did not improve from 0.14093
# Epoch 693/5000
#
# Epoch 00693: val_loss did not improve from 0.14093
# ...
# Epoch 4767/5000
#
# Epoch 04767: val_loss did not improve from 0.11281
# Epoch 4768/5000
#
# Epoch 04768: val_loss did not improve from 0.11281
# Epoch 4769/5000
#
# Epoch 04769: val_loss did not improve from 0.11281
# Epoch 4770/5000
#
# Epoch 04770: val_loss did not improve from 0.11281
# Epoch 4771/5000
#
# Epoch 04771: val_loss did not improve from 0.11281
# Epoch 4772/5000
#
# Epoch 04772: val_loss did not improve from 0.11281
# Epoch 4773/5000
#
# Epoch 04773: val_loss did not improve from 0.11281
# Epoch 4774/5000
#
# Epoch 04774: val_loss did not improve from 0.11281
# Epoch 4775/5000
#
# Epoch 04775: val_loss did not improve from 0.11281
# Epoch 4776/5000
#
# Epoch 04776: val_loss did not improve from 0.11281
# Epoch 4777/5000
#
# Epoch 04777: val_loss did not improve from 0.11281
# Epoch 4778/5000
#
# Epoch 04778: val_loss did not improve from 0.11281
# Epoch 4779/5000
#
# Epoch 04779: val_loss did not improve from 0.11281
# Epoch 4780/5000
#
# Epoch 04780: val_loss did not improve from 0.11281
# Epoch 4781/5000
#
# Epoch 04781: val_loss did not improve from 0.11281
# Epoch 4782/5000
#
# Epoch 04782: val_loss did not improve from 0.11281
# Epoch 4783/5000
#
# Epoch 04783: val_loss did not improve from 0.11281
# Epoch 4784/5000
#
# Epoch 04784: val_loss did not improve from 0.11281
# Epoch 4785/5000
#
# Epoch 04785: val_loss did not improve from 0.11281
# Epoch 4786/5000
#
# Epoch 04786: val_loss did not improve from 0.11281
# Epoch 4787/5000
#
# Epoch 04787: val_loss did not improve from 0.11281
# Epoch 4788/5000
# Epoch 04788: val_loss did not improve from 0.11281
# Epoch 4789/5000
#
# Epoch 04789: val_loss did not improve from 0.11281
# Epoch 4790/5000
#
# Epoch 04790: val_loss did not improve from 0.11281
# Epoch 4791/5000
#
# Epoch 04791: val_loss did not improve from 0.11281
# Epoch 4792/5000
#
# Epoch 04792: val_loss did not improve from 0.11281
# Epoch 4793/5000
#
# Epoch 04793: val_loss did not improve from 0.11281
# Epoch 4794/5000
#
# Epoch 04794: val_loss did not improve from 0.11281
# Epoch 4795/5000
#
# Epoch 04795: val_loss did not improve from 0.11281
# Epoch 4796/5000
#
# Epoch 04796: val_loss did not improve from 0.11281
# Epoch 4797/5000
#
# Epoch 04797: val_loss did not improve from 0.11281
# Epoch 4798/5000
#
# Epoch 04798: val_loss did not improve from 0.11281
# Epoch 4799/5000
#
# Epoch 04799: val_loss did not improve from 0.11281
# Epoch 4800/5000
#
# Epoch 04800: val_loss did not improve from 0.11281
# Epoch 4801/5000
#
# Epoch 04801: val_loss did not improve from 0.11281
# Epoch 4802/5000
#
# Epoch 04802: val_loss did not improve from 0.11281
# Epoch 4803/5000
#
# Epoch 04803: val_loss did not improve from 0.11281
# Epoch 4804/5000
#
# Epoch 04804: val_loss did not improve from 0.11281
# Epoch 4805/5000
#
# Epoch 04805: val_loss did not improve from 0.11281
# Epoch 4806/5000
#
# Epoch 04806: val_loss did not improve from 0.11281
# Epoch 4807/5000
#
# Epoch 04807: val_loss improved from 0.11281 to 0.11020, saving model to saved-model_mc.h5
# Epoch 4808/5000
#
# Epoch 04808: val_loss did not improve from 0.11020
# Epoch 4809/5000
#
# Epoch 04809: val_loss did not improve from 0.11020
# Epoch 4810/5000
#
# Epoch 04810: val_loss did not improve from 0.11020
# Epoch 4811/5000
#
# Epoch 04811: val_loss did not improve from 0.11020
# Epoch 4812/5000
#
# Epoch 04812: val_loss did not improve from 0.11020
# Epoch 4813/5000
#
# Epoch 04813: val_loss did not improve from 0.11020
# Epoch 4814/5000
#
# Epoch 04814: val_loss did not improve from 0.11020
# Epoch 4815/5000
#
# Epoch 04815: val_loss did not improve from 0.11020
# Epoch 4816/5000
#
# Epoch 04816: val_loss did not improve from 0.11020
# Epoch 4817/5000
#
# Epoch 04817: val_loss did not improve from 0.11020
# Epoch 4818/5000
#
# Epoch 04818: val_loss did not improve from 0.11020
# Epoch 4819/5000
#
# Epoch 04819: val_loss did not improve from 0.11020
# Epoch 4820/5000
#
# Epoch 04820: val_loss did not improve from 0.11020
# Epoch 4821/5000
#
# Epoch 04821: val_loss did not improve from 0.11020
# Epoch 4822/5000
#
# Epoch 04822: val_loss did not improve from 0.11020
# Epoch 4823/5000
#
# Epoch 04823: val_loss did not improve from 0.11020
# Epoch 4824/5000
#
# Epoch 04824: val_loss did not improve from 0.11020
# Epoch 4825/5000
#
# Epoch 04825: val_loss did not improve from 0.11020
# Epoch 4826/5000
#
# Epoch 04826: val_loss did not improve from 0.11020
# Epoch 4827/5000
#
# Epoch 04827: val_loss did not improve from 0.11020
# Epoch 4828/5000
#
# Epoch 04828: val_loss did not improve from 0.11020
# Epoch 4829/5000
#
# Epoch 04829: val_loss did not improve from 0.11020
# Epoch 4830/5000
#
# Epoch 04830: val_loss did not improve from 0.11020
# Epoch 4831/5000
#
# Epoch 04831: val_loss did not improve from 0.11020
# Epoch 4832/5000
#
# Epoch 04832: val_loss did not improve from 0.11020
# Epoch 4833/5000
#
# Epoch 04833: val_loss did not improve from 0.11020
# Epoch 4834/5000
#
# Epoch 04834: val_loss did not improve from 0.11020
# Epoch 4835/5000
#
# Epoch 04835: val_loss did not improve from 0.11020
# Epoch 4836/5000
#
# Epoch 04836: val_loss did not improve from 0.11020
# Epoch 4837/5000
#
# Epoch 04837: val_loss did not improve from 0.11020
# Epoch 4838/5000
#
# Epoch 04838: val_loss did not improve from 0.11020
# Epoch 4839/5000
#
# Epoch 04839: val_loss did not improve from 0.11020
# Epoch 4840/5000
#
# Epoch 04840: val_loss did not improve from 0.11020
# Epoch 4841/5000
#
# Epoch 04841: val_loss did not improve from 0.11020
# Epoch 4842/5000
#
# Epoch 04842: val_loss did not improve from 0.11020
# Epoch 4843/5000
#
# Epoch 04843: val_loss did not improve from 0.11020
# Epoch 4844/5000
#
# Epoch 04844: val_loss did not improve from 0.11020
# Epoch 4845/5000
#
# Epoch 04845: val_loss did not improve from 0.11020
# Epoch 4846/5000
#
# Epoch 04846: val_loss did not improve from 0.11020
# Epoch 4847/5000
#
# Epoch 04847: val_loss did not improve from 0.11020
# Epoch 4848/5000
#
# Epoch 04848: val_loss did not improve from 0.11020
# Epoch 4849/5000
#
# Epoch 04849: val_loss did not improve from 0.11020
# Epoch 4850/5000
#
# Epoch 04850: val_loss did not improve from 0.11020
# Epoch 4851/5000
#
# Epoch 04851: val_loss did not improve from 0.11020
# Epoch 4852/5000
#
# Epoch 04852: val_loss did not improve from 0.11020
# Epoch 4853/5000
#
# Epoch 04853: val_loss did not improve from 0.11020
# Epoch 4854/5000
#
# Epoch 04854: val_loss did not improve from 0.11020
# Epoch 4855/5000
#
# Epoch 04855: val_loss did not improve from 0.11020
# Epoch 4856/5000
#
# Epoch 04856: val_loss did not improve from 0.11020
# Epoch 4857/5000
#
# Epoch 04857: val_loss did not improve from 0.11020
# Epoch 4858/5000
#
# Epoch 04858: val_loss did not improve from 0.11020
# Epoch 4859/5000
#
# Epoch 04859: val_loss did not improve from 0.11020
# Epoch 4860/5000
#
# Epoch 04860: val_loss did not improve from 0.11020
# Epoch 4861/5000
#
# Epoch 04861: val_loss did not improve from 0.11020
# Epoch 4862/5000
#
# Epoch 04862: val_loss did not improve from 0.11020
# Epoch 4863/5000
#
# Epoch 04863: val_loss did not improve from 0.11020
# Epoch 4864/5000
#
# Epoch 04864: val_loss did not improve from 0.11020
# Epoch 4865/5000
#
# Epoch 04865: val_loss did not improve from 0.11020
# Epoch 4866/5000
#
# Epoch 04866: val_loss did not improve from 0.11020
# Epoch 4867/5000
#
# Epoch 04867: val_loss did not improve from 0.11020
# Epoch 4868/5000
#
# Epoch 04868: val_loss did not improve from 0.11020
# Epoch 4869/5000
#
# Epoch 04869: val_loss did not improve from 0.11020
# Epoch 4870/5000
#
# Epoch 04870: val_loss did not improve from 0.11020
# Epoch 4871/5000
#
# Epoch 04871: val_loss did not improve from 0.11020
# Epoch 4872/5000
#
# Epoch 04872: val_loss did not improve from 0.11020
# Epoch 4873/5000
#
# Epoch 04873: val_loss did not improve from 0.11020
# Epoch 4874/5000
#
# Epoch 04874: val_loss did not improve from 0.11020
# Epoch 4875/5000
#
# Epoch 04875: val_loss did not improve from 0.11020
# Epoch 4876/5000
#
# Epoch 04876: val_loss did not improve from 0.11020
# Epoch 4877/5000
#
# Epoch 04877: val_loss did not improve from 0.11020
# Epoch 4878/5000
#
# Epoch 04878: val_loss did not improve from 0.11020
# Epoch 4879/5000
#
# Epoch 04879: val_loss did not improve from 0.11020
# Epoch 4880/5000
#
# Epoch 04880: val_loss did not improve from 0.11020
# Epoch 4881/5000
#
# Epoch 04881: val_loss did not improve from 0.11020
# Epoch 4882/5000
#
# Epoch 04882: val_loss did not improve from 0.11020
# Epoch 4883/5000
#
# Epoch 04883: val_loss did not improve from 0.11020
# Epoch 4884/5000
#
# Epoch 04884: val_loss did not improve from 0.11020
# Epoch 4885/5000
#
# Epoch 04885: val_loss did not improve from 0.11020
# Epoch 4886/5000
#
# Epoch 04886: val_loss did not improve from 0.11020
# Epoch 4887/5000
#
# Epoch 04887: val_loss did not improve from 0.11020
# Epoch 4888/5000
#
# Epoch 04888: val_loss did not improve from 0.11020
# Epoch 4889/5000
#
# Epoch 04889: val_loss did not improve from 0.11020
# Epoch 4890/5000
#
# Epoch 04890: val_loss did not improve from 0.11020
# Epoch 4891/5000
#
# Epoch 04891: val_loss did not improve from 0.11020
# Epoch 4892/5000
#
# Epoch 04892: val_loss did not improve from 0.11020
# Epoch 4893/5000
#
# Epoch 04893: val_loss did not improve from 0.11020
# Epoch 4894/5000
#
# Epoch 04894: val_loss did not improve from 0.11020
# Epoch 4895/5000
#
# Epoch 04895: val_loss did not improve from 0.11020
# Epoch 4896/5000
#
# Epoch 04896: val_loss did not improve from 0.11020
# Epoch 4897/5000
#
# Epoch 04897: val_loss did not improve from 0.11020
# Epoch 4898/5000
#
# Epoch 04898: val_loss did not improve from 0.11020
# Epoch 4899/5000
#
# Epoch 04899: val_loss did not improve from 0.11020
# Epoch 4900/5000
#
# Epoch 04900: val_loss did not improve from 0.11020
# Epoch 4901/5000
#
# Epoch 04901: val_loss did not improve from 0.11020
# Epoch 4902/5000
#
# Epoch 04902: val_loss did not improve from 0.11020
# Epoch 4903/5000
#
# Epoch 04903: val_loss did not improve from 0.11020
# Epoch 4904/5000
#
# Epoch 04904: val_loss did not improve from 0.11020
# Epoch 4905/5000
#
# Epoch 04905: val_loss did not improve from 0.11020
# Epoch 4906/5000
#
# Epoch 04906: val_loss did not improve from 0.11020
# Epoch 4907/5000
#
# Epoch 04907: val_loss did not improve from 0.11020
# Epoch 4908/5000
#
# Epoch 04908: val_loss did not improve from 0.11020
# Epoch 4909/5000
#
# Epoch 04909: val_loss did not improve from 0.11020
# Epoch 4910/5000
#
# Epoch 04910: val_loss did not improve from 0.11020
# Epoch 4911/5000
#
# Epoch 04911: val_loss did not improve from 0.11020
# Epoch 4912/5000
#
# Epoch 04912: val_loss did not improve from 0.11020
# Epoch 4913/5000
#
# Epoch 04913: val_loss did not improve from 0.11020
# Epoch 4914/5000
#
# Epoch 04914: val_loss did not improve from 0.11020
# Epoch 4915/5000
#
# Epoch 04915: val_loss did not improve from 0.11020
# Epoch 4916/5000
#
# Epoch 04916: val_loss did not improve from 0.11020
# Epoch 4917/5000
#
# Epoch 04917: val_loss did not improve from 0.11020
# Epoch 4918/5000
#
# Epoch 04918: val_loss did not improve from 0.11020
# Epoch 4919/5000
#
# Epoch 04919: val_loss did not improve from 0.11020
# Epoch 4920/5000
#
# Epoch 04920: val_loss did not improve from 0.11020
# Epoch 4921/5000
#
# Epoch 04921: val_loss did not improve from 0.11020
# Epoch 4922/5000
#
# Epoch 04922: val_loss did not improve from 0.11020
# Epoch 4923/5000
#
# Epoch 04923: val_loss did not improve from 0.11020
# Epoch 4924/5000
#
# Epoch 04924: val_loss did not improve from 0.11020
# Epoch 4925/5000
#
# Epoch 04925: val_loss did not improve from 0.11020
# Epoch 4926/5000
#
# Epoch 04926: val_loss did not improve from 0.11020
# Epoch 4927/5000
#
# Epoch 04927: val_loss did not improve from 0.11020
# Epoch 4928/5000
#
# Epoch 04928: val_loss did not improve from 0.11020
# Epoch 4929/5000
#
# Epoch 04929: val_loss did not improve from 0.11020
# Epoch 4930/5000
#
# Epoch 04930: val_loss did not improve from 0.11020
# Epoch 4931/5000
#
# Epoch 04931: val_loss did not improve from 0.11020
# Epoch 4932/5000
#
# Epoch 04932: val_loss did not improve from 0.11020
# Epoch 4933/5000
#
# Epoch 04933: val_loss did not improve from 0.11020
# Epoch 4934/5000
#
# Epoch 04934: val_loss did not improve from 0.11020
# Epoch 4935/5000
#
# Epoch 04935: val_loss did not improve from 0.11020
# Epoch 4936/5000
#
# Epoch 04936: val_loss did not improve from 0.11020
# Epoch 4937/5000
#
# Epoch 04937: val_loss did not improve from 0.11020
# Epoch 4938/5000
#
# Epoch 04938: val_loss did not improve from 0.11020
# Epoch 4939/5000
#
# Epoch 04939: val_loss did not improve from 0.11020
# Epoch 4940/5000
#
# Epoch 04940: val_loss did not improve from 0.11020
# Epoch 4941/5000
#
# Epoch 04941: val_loss did not improve from 0.11020
# Epoch 4942/5000
#
# Epoch 04942: val_loss did not improve from 0.11020
# Epoch 4943/5000
#
# Epoch 04943: val_loss did not improve from 0.11020
# Epoch 4944/5000
#
# Epoch 04944: val_loss did not improve from 0.11020
# Epoch 4945/5000
#
# Epoch 04945: val_loss did not improve from 0.11020
# Epoch 4946/5000
#
# Epoch 04946: val_loss did not improve from 0.11020
# Epoch 4947/5000
#
# Epoch 04947: val_loss did not improve from 0.11020
# Epoch 4948/5000
#
# Epoch 04948: val_loss did not improve from 0.11020
# Epoch 4949/5000
#
# Epoch 04949: val_loss did not improve from 0.11020
# Epoch 4950/5000
#
# Epoch 04950: val_loss did not improve from 0.11020
# Epoch 4951/5000
#
# Epoch 04951: val_loss did not improve from 0.11020
# Epoch 4952/5000
#
# Epoch 04952: val_loss did not improve from 0.11020
# Epoch 4953/5000
#
# Epoch 04953: val_loss did not improve from 0.11020
# Epoch 4954/5000
#
# Epoch 04954: val_loss did not improve from 0.11020
# Epoch 4955/5000
#
# Epoch 04955: val_loss did not improve from 0.11020
# Epoch 4956/5000
#
# Epoch 04956: val_loss did not improve from 0.11020
# Epoch 4957/5000
#
# Epoch 04957: val_loss did not improve from 0.11020
# Epoch 4958/5000
#
# Epoch 04958: val_loss did not improve from 0.11020
# Epoch 4959/5000
#
# Epoch 04959: val_loss did not improve from 0.11020
# Epoch 4960/5000
#
# Epoch 04960: val_loss did not improve from 0.11020
# Epoch 4961/5000
#
# Epoch 04961: val_loss did not improve from 0.11020
# Epoch 4962/5000
#
# Epoch 04962: val_loss did not improve from 0.11020
# Epoch 4963/5000
#
# Epoch 04963: val_loss did not improve from 0.11020
# Epoch 4964/5000
#
# Epoch 04964: val_loss did not improve from 0.11020
# Epoch 4965/5000
#
# Epoch 04965: val_loss did not improve from 0.11020
# Epoch 4966/5000
#
# Epoch 04966: val_loss did not improve from 0.11020
# Epoch 4967/5000
#
# Epoch 04967: val_loss did not improve from 0.11020
# Epoch 4968/5000
#
# Epoch 04968: val_loss did not improve from 0.11020
# Epoch 4969/5000
#
# Epoch 04969: val_loss did not improve from 0.11020
# Epoch 4970/5000
#
# Epoch 04970: val_loss did not improve from 0.11020
# Epoch 4971/5000
#
# Epoch 04971: val_loss did not improve from 0.11020
# Epoch 4972/5000
#
# Epoch 04972: val_loss did not improve from 0.11020
# Epoch 4973/5000
#
# Epoch 04973: val_loss did not improve from 0.11020
# Epoch 4974/5000
#
# Epoch 04974: val_loss did not improve from 0.11020
# Epoch 4975/5000
#
# Epoch 04975: val_loss did not improve from 0.11020
# Epoch 4976/5000
#
# Epoch 04976: val_loss did not improve from 0.11020
# Epoch 4977/5000
#
# Epoch 04977: val_loss did not improve from 0.11020
# Epoch 4978/5000
#
# Epoch 04978: val_loss did not improve from 0.11020
# Epoch 4979/5000
#
# Epoch 04979: val_loss did not improve from 0.11020
# Epoch 4980/5000
#
# Epoch 04980: val_loss did not improve from 0.11020
# Epoch 4981/5000
#
# Epoch 04981: val_loss did not improve from 0.11020
# Epoch 4982/5000
#
# Epoch 04982: val_loss did not improve from 0.11020
# Epoch 4983/5000
#
# Epoch 04983: val_loss did not improve from 0.11020
# Epoch 4984/5000
#
# Epoch 04984: val_loss did not improve from 0.11020
# Epoch 4985/5000
#
# Epoch 04985: val_loss did not improve from 0.11020
# Epoch 4986/5000
#
# Epoch 04986: val_loss did not improve from 0.11020
# Epoch 4987/5000
#
# Epoch 04987: val_loss did not improve from 0.11020
# Epoch 4988/5000
#
# Epoch 04988: val_loss did not improve from 0.11020
# Epoch 4989/5000
#
# Epoch 04989: val_loss did not improve from 0.11020
# Epoch 4990/5000
#
# Epoch 04990: val_loss did not improve from 0.11020
# Epoch 4991/5000
#
# Epoch 04991: val_loss did not improve from 0.11020
# Epoch 4992/5000
#
# Epoch 04992: val_loss did not improve from 0.11020
# Epoch 4993/5000
#
# Epoch 04993: val_loss did not improve from 0.11020
# Epoch 4994/5000
#
# Epoch 04994: val_loss did not improve from 0.11020
# Epoch 4995/5000
#
# Epoch 04995: val_loss did not improve from 0.11020
# Epoch 4996/5000
#
# Epoch 04996: val_loss did not improve from 0.11020
# Epoch 4997/5000
#
# Epoch 04997: val_loss did not improve from 0.11020
# Epoch 4998/5000
#
# Epoch 04998: val_loss did not improve from 0.11020
# Epoch 4999/5000
#
# Epoch 04999: val_loss did not improve from 0.11020
# Epoch 5000/5000
#
# Epoch 05000: val_loss did not improve from 0.11020

# %% [markdown]
# ## Plots

# %%
df_hist = pd.DataFrame(hist.history)
df_hist.plot(subplots=True, figsize=(15,15))
#print(df_hist['val_loss'].min())
#df_hist[df_hist['val_loss']<=0.1054]
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000237E3DA6DD8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000237E5327EB8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000237E535A0B8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000237E5383278>],
#       dtype=object)

# %% [markdown]
# ##  Prediction

# %%
encoder = Model(inputs=autoencoder.inputs,outputs=autoencoder.get_layer('encoded').output)
test_g = datagen(len(val_list_of_writers)*4,val_path,val_list_of_writers, hshift = (-12,12), vis=True)
vx,vy = next(test_g)
print(vx.shape,vy[0].shape)
ids = vy[0].reshape(-1,1)
imagenames = vy[1].reshape(-1,1)
preds = encoder.predict(vx).reshape((-1,512))
# print(ids.shape,preds.shape)
# 
data=[]
for i in range(len(vx)):
    data.append([ids[i][0],imagenames[i][0],preds[i]])
df_data = pd.DataFrame(data=data, columns=['identity','imagename','latent'])

py = autoencoder.predict(vx[:10])
f,ax = plt.subplots(len(vx[:10]),2)
f.subplots_adjust(hspace = .00, wspace=.05)
f.set_size_inches(5,len(vx[:10])*3)
ax[0,0].set_title('TRUE')
ax[0,1].set_title('PRED')
for i in range(len(vx[:10])):
#     print(vy[0][i], vy[1][i])
    ax[i,0].imshow(vx[i].reshape((64,64)))
    ax[i,0].axis('off')
    
    ax[i,1].imshow(py[i].reshape((64,64)))
    ax[i,1].axis('off')
# Out:
# (3808, 64, 64, 1) (3808,)

# %%
cos_dist_out = cosine_similarity(list(df_data['latent'].values))
queried_count, idx_count, tp, tn, fp, fn = 0,0,0,0,0,0
cos_thresh = 0.63
data_result = []
fp_list = []
fn_list = []
r_counter = 0
stop_at = 10
prev_query = ''
prev_given = ''
given_count = 0
# total = cos_dist_out.shape[0]
for row in tqdm(cos_dist_out):
    #print(row)
    c_counter = 0
    given_idx = df_data.iloc[r_counter]['identity']
    given_img = df_data.iloc[r_counter]['imagename']
    for col in row:
        queried_idx = df_data.iloc[c_counter]['identity']
        queried_img = df_data.iloc[c_counter]['imagename']
        if int(given_idx) == int(queried_idx) and cos_dist_out[r_counter][c_counter]>cos_thresh:
            tp += 1
        if int(given_idx) != int(queried_idx) and cos_dist_out[r_counter][c_counter]<cos_thresh:
            tn += 1
        if int(given_idx) != int(queried_idx) and cos_dist_out[r_counter][c_counter]>cos_thresh:
            fp += 1
            fp_list.append(os.path.join(queried_idx,queried_img))
        if int(given_idx) == int(queried_idx) and cos_dist_out[r_counter][c_counter]<cos_thresh:
            fn += 1
            fn_list.append(os.path.join(queried_idx,queried_img))
        if int(given_idx) == int(queried_idx):
            idx_count += 1
#             print('--i--',idx_count,'--i--')
#             print(given_idx,queried_idx)
        if prev_query != queried_idx:
#             print('--q--',queried_count,'--q--')
            queried_count += 1
        c_counter += 1
        prev_query = queried_idx
#         if queried_count == stop_at:
#             break
    precision = tp/(fp+tp)
    recall = tp/(tp+fn)
    f1 = 2*(precision*recall)/(precision+recall)
    total = np.sum((tp,tn,fp,fn))
    accuracy = (tp+tn)/total
    data_result.append([given_idx,given_img, idx_count, tp, tn, fp, fn,precision,recall,f1,accuracy, total, fp_list, fn_list])
    if prev_given != given_idx:
#         print('----',given_count,'-----')
        given_count+=1
    r_counter += 1
    prev_given = given_idx
    queried_count, idx_count, tp, tn, fp, fn = 0, 0, 0, 0, 0, 0
    fp_list = []
    fn_list = []
# Out:
#  38%|███▊      | 1450/3808 [19:11<33:15,  1.18it/s]

# %%
df_cos_dist_out = pd.DataFrame(data_result, columns=['identity','imagename','total_images_identity','TP','TN','FP','FN','precision','recall','f1','accuracy','total_images', 'FP_List','FN_List'])
df_cos_dist_out=df_cos_dist_out.sort_values(by='identity').reset_index().drop(columns=['index'])
df_cos_dist_out.to_csv('results-DL_AE_Maxpool_1x1x512_Seen.csv')

total = df_cos_dist_out.shape[0]
total_images_identity = df_cos_dist_out['total_images_identity']
tps = df_cos_dist_out['TP'].sum()
fps = df_cos_dist_out['FP'].sum()
tns = df_cos_dist_out['TN'].sum()
fns = df_cos_dist_out['FN'].sum()
precision = tps/(fps+tps)
recall = tps/(tps+fns)
f1 = 2*(precision*recall)/(precision+recall)
print('precision:',precision,'\nrecall:',recall,'\nf1:',f1)
acc = df_cos_dist_out['accuracy'].mean()
print('Intra Writer Accuracy (Type 1):',np.mean(df_cos_dist_out['TP']/total_images_identity))
print('Inter Writer Accuracy (Type 2)::',tns/total/total)
print('acc:',acc)

# %%
test_im_normal = vx[29]#255.0-cv2.imread('../Handwriting/cleaned_AND_data_64x64/0005aa_num1.png',0)
test_im_shifted = cv2.imread(os.path.join('seen-dataset/TrainingSet/','0005a_num2.png'),0)
f,ax = plt.subplots(1,2)
f.subplots_adjust(hspace = .00, wspace=.05)
f.set_size_inches(5,1*3)
ax[0].imshow(test_im_normal.reshape((64,64)))
ax[0].axis('off')

ax[1].imshow(test_im_shifted.reshape((64,64)))
ax[1].axis('off')
ax[0].set_title('Left Input')
ax[1].set_title('Right Input')
acc = df_cos_dist_out['accuracy'].mean()
#print("Accuracy: "+str(acc))
