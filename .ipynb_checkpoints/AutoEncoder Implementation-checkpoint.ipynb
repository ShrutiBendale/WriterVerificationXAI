# %% [markdown]
# ## Importing libraries

# %%
import matplotlib.pyplot as plt
import os
import numpy as np
import random
import cv2
import time
from keras import losses
from keras.models import Model
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.layers import Input, Conv2D, MaxPooling2D, BatchNormalization, Activation, Reshape, UpSampling2D, Dense
from keras.layers.merge import concatenate
from keras.layers import Flatten
from keras.utils import to_categorical
from keras.optimizers import Adadelta, SGD, Adam
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from keras.layers import concatenate
from keras.utils.vis_utils import model_to_dot
from keras.utils import np_utils
from IPython.display import SVG
from tqdm import tqdm, tqdm_notebook

# %% [markdown]
# ## Importing data from CSVs.

# %%
features_data = pd.read_csv("15features.csv")
training_data = pd.read_csv("seen-dataset/dataset_seen_training_siamese.csv")
validation_data = pd.read_csv("seen-dataset/dataset_seen_validation_siamese.csv")

training_data = training_data.drop('Unnamed: 0',1)
validation_data = validation_data.drop('Unnamed: 0',1)

train_path = 'seen-dataset/TrainingSet/'
train_images = os.listdir(train_path)
#print(len(train_images))
val_path = 'seen-dataset/ValidationSet/'
val_images = os.listdir(val_path)

columns = features_data.columns

#Get the unique no of values a given feature can take.
features_values = []
for i in columns[1:]:
    #print(i)
    features_values.append(features_data[i].unique().shape[0])
features_values
# Out:
# [2, 3, 3, 3, 2, 2, 4, 2, 2, 4, 2, 3, 4, 2, 2]

# %% [markdown]
# ## Datagen

# %%
def datagen(batch_size,image_path,list_of_writers, hshift = (-64,64) ,vis=False):
    counter = 0

    while True:
        counter = 0
        w_ids,ids = [],[]
        writer_indexes = np.random.randint(0,len(list_of_writers),batch_size)
        x,y,writers = [],[],[]
        for writer_index in writer_indexes:
            writer = list_of_writers[writer_index]
    
            loaded_image = cv2.imread(os.path.join(image_path,writer),0)
            rand = np.random.randint(hshift[0],hshift[1])
            loaded_image_shifted=np.roll(axis=0,a=loaded_image,shift=rand)

            x.append(255.0-loaded_image_shifted.reshape((64,64,1)))
            y.append(255.0-loaded_image.reshape((64,64,1)))
            w_ids.append(writer[:4])
            writers.append(writer)
            ids.append(writer_index)
            
            counter+=1
        if counter <= batch_size:
            if vis== True:
                yield np.array(x)/255.0,[np.array(w_ids),np.array(writers)]
            else:
                yield np.array(x)/255.0,np.array(y)/255.0

# %% [markdown]
# ## AutoEncoder

# %%
input_img = Input(shape=(64, 64, 1))  # adapt this if using `channels_first` image data format

x = Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same', name='encoded')(x)

x = Conv2D(512, (3, 3), activation='relu', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same',name='output')(x)

autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy', metrics=['accuracy'])
# autoencoder.summary()

# %% [markdown]
# ##  Generators

# %%
train_path = 'seen-dataset/TrainingSet/'
train_images = os.listdir(train_path)
#len(train_images)
val_path = 'seen-dataset/ValidationSet/'
val_images = os.listdir(val_path)
#len(val_images)

train_list_of_writers = train_images
val_list_of_writers = val_images
batch_size = 64

training_datagen = datagen(batch_size,train_path,train_list_of_writers, hshift = (-10,10))
validation_datagen = datagen(batch_size,val_path,val_list_of_writers, hshift = (-10,10))

# %% [markdown]
# ## SVG

# %%
#SVG(model_to_dot(autoencoder, show_layer_names=True, show_shapes=True).create(prog='dot', format='svg'))

# %% [markdown]
# ## Model Checkpoint and Early Stopping

# %%
mc = ModelCheckpoint(filepath='saved-model_mc.h5', 
                     monitor='val_loss',period=1,save_best_only=True,save_weights_only=True,mode='auto',verbose=3)
es = EarlyStopping(patience=10000, monitor='val_loss', min_delta=0.0005, mode='auto')
#autoencoder.load_weights('simple_ae_maxpool_less_weights_v3.h5')

# %% [markdown]
# ## Fitting the generator

# %%
EPOCHS = 100

hist = autoencoder.fit_generator(training_datagen, callbacks=[mc,es]
                                    , epochs=EPOCHS
                                    , steps_per_epoch = 1
                                    , validation_data = validation_datagen
                                    , validation_steps = 1
                                    , verbose = 3                                    
                                   )
autoencoder.save_weights("saved-model_v2.h5")
encoder = Model(inputs=autoencoder.inputs,outputs=autoencoder.get_layer('encoded').output)
# Out:
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 0.68727, saving model to saved-model_mc.h5
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 0.68727 to 0.67539, saving model to saved-model_mc.h5
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 0.67539 to 0.65104, saving model to saved-model_mc.h5
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 0.65104 to 0.59540, saving model to saved-model_mc.h5
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 0.59540 to 0.44560, saving model to saved-model_mc.h5
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 0.44560 to 0.39477, saving model to saved-model_mc.h5
# Epoch 7/100
#
# Epoch 00007: val_loss did not improve from 0.39477
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 0.39477 to 0.30812, saving model to saved-model_mc.h5
# Epoch 9/100
#
# Epoch 00009: val_loss did not improve from 0.30812
# Epoch 10/100
#
# Epoch 00010: val_loss did not improve from 0.30812
# Epoch 11/100
#
# Epoch 00011: val_loss did not improve from 0.30812
# Epoch 12/100
#
# Epoch 00012: val_loss did not improve from 0.30812
# Epoch 13/100
#
# Epoch 00013: val_loss did not improve from 0.30812
# Epoch 14/100
#
# Epoch 00014: val_loss did not improve from 0.30812
# Epoch 15/100
#
# Epoch 00015: val_loss did not improve from 0.30812
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 0.30812 to 0.30597, saving model to saved-model_mc.h5
# Epoch 17/100
#
# Epoch 00017: val_loss did not improve from 0.30597
# Epoch 18/100
#
# Epoch 00018: val_loss improved from 0.30597 to 0.19168, saving model to saved-model_mc.h5
# Epoch 19/100
#
# Epoch 00019: val_loss did not improve from 0.19168
# Epoch 20/100
#
# Epoch 00020: val_loss did not improve from 0.19168
# Epoch 21/100
#
# Epoch 00021: val_loss did not improve from 0.19168
# Epoch 22/100
#
# Epoch 00022: val_loss did not improve from 0.19168
# Epoch 23/100
#
# Epoch 00023: val_loss did not improve from 0.19168
# Epoch 24/100
#
# Epoch 00024: val_loss did not improve from 0.19168
# Epoch 25/100
#
# Epoch 00025: val_loss did not improve from 0.19168
# Epoch 26/100
#
# Epoch 00026: val_loss did not improve from 0.19168
# Epoch 27/100
#
# Epoch 00027: val_loss did not improve from 0.19168
# Epoch 28/100
#
# Epoch 00028: val_loss did not improve from 0.19168
# Epoch 29/100
#
# Epoch 00029: val_loss did not improve from 0.19168
# Epoch 30/100
#
# Epoch 00030: val_loss did not improve from 0.19168
# Epoch 31/100
#
# Epoch 00031: val_loss did not improve from 0.19168
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 0.19168
# Epoch 33/100
#
# Epoch 00033: val_loss did not improve from 0.19168
# Epoch 34/100
#
# Epoch 00034: val_loss did not improve from 0.19168
# Epoch 35/100
#
# Epoch 00035: val_loss did not improve from 0.19168
# Epoch 36/100
#
# Epoch 00036: val_loss did not improve from 0.19168
# Epoch 37/100
#
# Epoch 00037: val_loss did not improve from 0.19168
# Epoch 38/100
#
# Epoch 00038: val_loss did not improve from 0.19168
# Epoch 39/100
#
# Epoch 00039: val_loss did not improve from 0.19168
# Epoch 40/100
#
# Epoch 00040: val_loss did not improve from 0.19168
# Epoch 41/100
#
# Epoch 00041: val_loss did not improve from 0.19168
# Epoch 42/100
#
# Epoch 00042: val_loss did not improve from 0.19168
# Epoch 43/100
#
# Epoch 00043: val_loss did not improve from 0.19168
# Epoch 44/100
#
# Epoch 00044: val_loss did not improve from 0.19168
# Epoch 45/100
#
# Epoch 00045: val_loss did not improve from 0.19168
# Epoch 46/100
#
# Epoch 00046: val_loss did not improve from 0.19168
# Epoch 47/100
#
# Epoch 00047: val_loss did not improve from 0.19168
# Epoch 48/100
#
# Epoch 00048: val_loss did not improve from 0.19168
# Epoch 49/100
#
# Epoch 00049: val_loss did not improve from 0.19168
# Epoch 50/100
#
# Epoch 00050: val_loss did not improve from 0.19168
# Epoch 51/100
#
# Epoch 00051: val_loss improved from 0.19168 to 0.19150, saving model to saved-model_mc.h5
# Epoch 52/100
#
# Epoch 00052: val_loss did not improve from 0.19150
# Epoch 53/100
#
# Epoch 00053: val_loss did not improve from 0.19150
# Epoch 54/100
#
# Epoch 00054: val_loss did not improve from 0.19150
# Epoch 55/100
#
# Epoch 00055: val_loss improved from 0.19150 to 0.18940, saving model to saved-model_mc.h5
# Epoch 56/100
#
# Epoch 00056: val_loss did not improve from 0.18940
# Epoch 57/100
#
# Epoch 00057: val_loss did not improve from 0.18940
# Epoch 58/100
#
# Epoch 00058: val_loss did not improve from 0.18940
# Epoch 59/100
#
# Epoch 00059: val_loss did not improve from 0.18940
# Epoch 60/100
#
# Epoch 00060: val_loss did not improve from 0.18940
# Epoch 61/100
#
# Epoch 00061: val_loss did not improve from 0.18940
# Epoch 62/100
#
# Epoch 00062: val_loss improved from 0.18940 to 0.17872, saving model to saved-model_mc.h5
# Epoch 63/100
#
# Epoch 00063: val_loss improved from 0.17872 to 0.17592, saving model to saved-model_mc.h5
# Epoch 64/100
#
# Epoch 00064: val_loss did not improve from 0.17592
# Epoch 65/100
#
# Epoch 00065: val_loss did not improve from 0.17592
# Epoch 66/100
#
# Epoch 00066: val_loss improved from 0.17592 to 0.16859, saving model to saved-model_mc.h5
# Epoch 67/100
#
# Epoch 00067: val_loss did not improve from 0.16859
# Epoch 68/100
#
# Epoch 00068: val_loss did not improve from 0.16859
# Epoch 69/100
#
# Epoch 00069: val_loss did not improve from 0.16859
# Epoch 70/100
#
# Epoch 00070: val_loss did not improve from 0.16859
# Epoch 71/100
#
# Epoch 00071: val_loss did not improve from 0.16859
# Epoch 72/100
#
# Epoch 00072: val_loss improved from 0.16859 to 0.16371, saving model to saved-model_mc.h5
# Epoch 73/100
#
# Epoch 00073: val_loss did not improve from 0.16371
# Epoch 74/100
#
# Epoch 00074: val_loss did not improve from 0.16371
# Epoch 75/100
#
# Epoch 00075: val_loss did not improve from 0.16371
# Epoch 76/100
#
# Epoch 00076: val_loss did not improve from 0.16371
# Epoch 77/100
#
# Epoch 00077: val_loss did not improve from 0.16371
# Epoch 78/100
#
# Epoch 00078: val_loss did not improve from 0.16371
# Epoch 79/100
#
# Epoch 00079: val_loss did not improve from 0.16371
# Epoch 80/100
#
# Epoch 00080: val_loss did not improve from 0.16371
# Epoch 81/100
#
# Epoch 00081: val_loss did not improve from 0.16371
# Epoch 82/100
#
# Epoch 00082: val_loss did not improve from 0.16371
# Epoch 83/100
#
# Epoch 00083: val_loss did not improve from 0.16371
# Epoch 84/100
#
# Epoch 00084: val_loss did not improve from 0.16371
# Epoch 85/100
#
# Epoch 00085: val_loss did not improve from 0.16371
# Epoch 86/100
#
# Epoch 00086: val_loss did not improve from 0.16371
# Epoch 87/100
#
# Epoch 00087: val_loss did not improve from 0.16371
# Epoch 88/100
#
# Epoch 00088: val_loss did not improve from 0.16371
# Epoch 89/100
#
# Epoch 00089: val_loss did not improve from 0.16371
# Epoch 90/100
#
# Epoch 00090: val_loss did not improve from 0.16371
# Epoch 91/100
#
# Epoch 00091: val_loss did not improve from 0.16371
# Epoch 92/100

# %% [markdown]
# ## Plots

# %%
df_hist = pd.DataFrame(hist.history)
df_hist.plot(subplots=True, figsize=(15,15))
#print(df_hist['val_loss'].min())
#df_hist[df_hist['val_loss']<=0.1054]

# %% [markdown]
# ##  Prediction

# %%
encoder = Model(inputs=autoencoder.inputs,outputs=autoencoder.get_layer('encoded').output)
test_g = datagen(len(val_list_of_writers)*4,val_path,val_list_of_writers, hshift = (-12,12), vis=True)
vx,vy = next(test_g)
print(vx.shape,vy[0].shape)
ids = vy[0].reshape(-1,1)
imagenames = vy[1].reshape(-1,1)
preds = encoder.predict(vx).reshape((-1,512))
# print(ids.shape,preds.shape)
# 
data=[]
for i in range(len(vx)):
    data.append([ids[i][0],imagenames[i][0],preds[i]])
df_data = pd.DataFrame(data=data, columns=['identity','imagename','latent'])

py = autoencoder.predict(vx[:10])
f,ax = plt.subplots(len(vx[:10]),2)
f.subplots_adjust(hspace = .00, wspace=.05)
f.set_size_inches(5,len(vx[:10])*3)
ax[0,0].set_title('TRUE')
ax[0,1].set_title('PRED')
for i in range(len(vx[:10])):
#     print(vy[0][i], vy[1][i])
    ax[i,0].imshow(vx[i].reshape((64,64)))
    ax[i,0].axis('off')
    
    ax[i,1].imshow(py[i].reshape((64,64)))
    ax[i,1].axis('off')

# %%
cos_dist_out = cosine_similarity(list(df_data['latent'].values))
queried_count, idx_count, tp, tn, fp, fn = 0,0,0,0,0,0
cos_thresh = 0.63
data_result = []
fp_list = []
fn_list = []
r_counter = 0
stop_at = 10
prev_query = ''
prev_given = ''
given_count = 0
# total = cos_dist_out.shape[0]
for row in tqdm(cos_dist_out):
    #print(row)
    c_counter = 0
    given_idx = df_data.iloc[r_counter]['identity']
    given_img = df_data.iloc[r_counter]['imagename']
    for col in row:
        queried_idx = df_data.iloc[c_counter]['identity']
        queried_img = df_data.iloc[c_counter]['imagename']
        if int(given_idx) == int(queried_idx) and cos_dist_out[r_counter][c_counter]>cos_thresh:
            tp += 1
        if int(given_idx) != int(queried_idx) and cos_dist_out[r_counter][c_counter]<cos_thresh:
            tn += 1
        if int(given_idx) != int(queried_idx) and cos_dist_out[r_counter][c_counter]>cos_thresh:
            fp += 1
            fp_list.append(os.path.join(queried_idx,queried_img))
        if int(given_idx) == int(queried_idx) and cos_dist_out[r_counter][c_counter]<cos_thresh:
            fn += 1
            fn_list.append(os.path.join(queried_idx,queried_img))
        if int(given_idx) == int(queried_idx):
            idx_count += 1
#             print('--i--',idx_count,'--i--')
#             print(given_idx,queried_idx)
        if prev_query != queried_idx:
#             print('--q--',queried_count,'--q--')
            queried_count += 1
        c_counter += 1
        prev_query = queried_idx
#         if queried_count == stop_at:
#             break
    precision = tp/(fp+tp)
    recall = tp/(tp+fn)
    f1 = 2*(precision*recall)/(precision+recall)
    total = np.sum((tp,tn,fp,fn))
    accuracy = (tp+tn)/total
    data_result.append([given_idx,given_img, idx_count, tp, tn, fp, fn,precision,recall,f1,accuracy, total, fp_list, fn_list])
    if prev_given != given_idx:
#         print('----',given_count,'-----')
        given_count+=1
    r_counter += 1
    prev_given = given_idx
    queried_count, idx_count, tp, tn, fp, fn = 0, 0, 0, 0, 0, 0
    fp_list = []
    fn_list = []

# %%
df_cos_dist_out = pd.DataFrame(data_result, columns=['identity','imagename','total_images_identity','TP','TN','FP','FN','precision','recall','f1','accuracy','total_images', 'FP_List','FN_List'])
df_cos_dist_out=df_cos_dist_out.sort_values(by='identity').reset_index().drop(columns=['index'])
df_cos_dist_out.to_csv('results-DL_AE_Maxpool_1x1x512_Seen.csv')

total = df_cos_dist_out.shape[0]
total_images_identity = df_cos_dist_out['total_images_identity']
tps = df_cos_dist_out['TP'].sum()
fps = df_cos_dist_out['FP'].sum()
tns = df_cos_dist_out['TN'].sum()
fns = df_cos_dist_out['FN'].sum()
precision = tps/(fps+tps)
recall = tps/(tps+fns)
f1 = 2*(precision*recall)/(precision+recall)
print('precision:',precision,'\nrecall:',recall,'\nf1:',f1)
acc = df_cos_dist_out['accuracy'].mean()
print('Intra Writer Accuracy (Type 1):',np.mean(df_cos_dist_out['TP']/total_images_identity))
print('Inter Writer Accuracy (Type 2)::',tns/total/total)
print('acc:',acc)

# %%
test_im_normal = vx[29]#255.0-cv2.imread('../Handwriting/cleaned_AND_data_64x64/0005aa_num1.png',0)
test_im_shifted = cv2.imread(os.path.join('seen-dataset/TrainingSet/','0005a_num2.png'),0)
f,ax = plt.subplots(1,2)
f.subplots_adjust(hspace = .00, wspace=.05)
f.set_size_inches(5,1*3)
ax[0].imshow(test_im_normal.reshape((64,64)))
ax[0].axis('off')

ax[1].imshow(test_im_shifted.reshape((64,64)))
ax[1].axis('off')
ax[0].set_title('Left Input')
ax[1].set_title('Right Input')
acc = df_cos_dist_out['accuracy'].mean()
#print("Accuracy: "+str(acc))
